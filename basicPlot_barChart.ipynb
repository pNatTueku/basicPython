# %%
# import libraries

import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('mpg.csv')
data.shape
# Out:
# (398, 9)

# %%
data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model_year        int64
# origin            int64
# name             object
# dtype: object

# %%
data.isna().any()
# Out:
# mpg             False
# cylinders       False
# displacement    False
# horsepower      False
# weight          False
# acceleration    False
# model_year      False
# origin          False
# name            False
# dtype: bool

# %%
data.groupby('cylinders').mean(numeric_only = True).plot.bar()
# Out:
# <AxesSubplot: xlabel='cylinders'>

# %%
data.groupby('cylinders').mean(numeric_only = True)['mpg'].plot.bar(color = 'blue', ylabel = 'mpg')
# Out:
# <AxesSubplot: xlabel='cylinders', ylabel='mpg'>

# %%
data.groupby('cylinders').mean(numeric_only = True)['displacement'].plot.bar(color = 'orange', ylabel = 'displacement')
# Out:
# <AxesSubplot: xlabel='cylinders', ylabel='displacement'>

# %%
data.groupby('cylinders').mean(numeric_only = True)['weight'].plot.barh(color = 'green', ylabel = 'weight', title = 'cylenders vs weight')
# Out:
# <AxesSubplot: title={'center': 'cylenders vs weight'}, ylabel='weight'>

# %%
data.groupby('cylinders').mean(numeric_only = True)['weight'].sort_values(ascending = False).plot.barh(color = 'green', ylabel = 'weight', title = 'cylenders vs weight')
# Out:
# <AxesSubplot: title={'center': 'cylenders vs weight'}, ylabel='weight'>
