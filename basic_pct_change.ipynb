# %%
# import libraries

import pandas as pd
import yfinance as yf
from datetime import date

# %%
start = "2023-01-01"
end = date.today()

# %%
arm_df = yf.download("ARM", start = start, end = end, progress = False) # raw data
arm_df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2023-09-14  56.099998  66.279999  55.540001  63.590000  63.590000  130534500
# 2023-09-15  68.629997  69.000000  60.750000  60.750000  60.750000   74568900
# 2023-09-18  57.950001  58.741001  55.020000  58.000000  58.000000   34571900
# 2023-09-19  56.250000  56.779999  53.880001  55.169998  55.169998   18308600
# 2023-09-20  55.169998  55.400002  51.520000  52.910000  52.910000   16369500

# %%
arm_df.shape
# Out:
# (103, 6)

# %%
arm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 103 entries, 2023-09-14 to 2024-02-09
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       103 non-null    float64
#  1   High       103 non-null    float64
#  2   Low        103 non-null    float64
#  3   Close      103 non-null    float64
#  4   Adj Close  103 non-null    float64
#  5   Volume     103 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 5.6 KB

# %%
arm_df.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  103.000000  103.000000  103.000000  103.000000  103.000000
# mean    62.406049   64.220748   60.764049   62.623301   62.623301
# std     10.551151   12.396373   10.347883   11.642216   11.642216
# min     47.220001   49.660000   46.500000   47.869999   47.869999
# 25%     53.225000   54.199999   51.669500   53.045000   53.045000
# 50%     61.509998   63.689999   60.790001   61.759998   61.759998
# 75%     70.755001   72.244999   69.150002   70.702499   70.702499
# max    105.989998  126.584999  102.089996  115.209999  115.209999
#
#              Volume
# count  1.030000e+02
# mean   1.027946e+07
# std    1.783577e+07
# min    2.268900e+06
# 25%    4.299100e+06
# 50%    6.206500e+06
# 75%    8.128650e+06
# max    1.305345e+08

# %%
arm_df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2023-09-14  56.099998  66.279999  55.540001  63.590000  63.590000  130534500
# 2023-09-15  68.629997  69.000000  60.750000  60.750000  60.750000   74568900
# 2023-09-18  57.950001  58.741001  55.020000  58.000000  58.000000   34571900
# 2023-09-19  56.250000  56.779999  53.880001  55.169998  55.169998   18308600
# 2023-09-20  55.169998  55.400002  51.520000  52.910000  52.910000   16369500

# %%
arm_df.pct_change() # change by day
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2023-09-14       NaN       NaN       NaN       NaN        NaN       NaN
# 2023-09-15  0.223351  0.041038  0.093806 -0.044661  -0.044661 -0.428742
# 2023-09-18 -0.155617 -0.148681 -0.094321 -0.045267  -0.045267 -0.536376
# 2023-09-19 -0.029336 -0.033384 -0.020720 -0.048793  -0.048793 -0.470420
# 2023-09-20 -0.019200 -0.024304 -0.043801 -0.040964  -0.040964 -0.105912
# ...              ...       ...       ...       ...        ...       ...
# 2024-02-05  0.012518  0.032384  0.022857  0.031972   0.031972  0.695778
# 2024-02-06  0.041811  0.015751  0.002793 -0.003958  -0.003958 -0.049407
# 2024-02-07 -0.025733  0.029954  0.006267  0.055221   0.055221  2.304993
# 2024-02-08  0.292049  0.628941  0.301038  0.478899   0.478899  3.670729
# 2024-02-09  0.122656 -0.069242  0.086064  0.011590   0.011590 -0.548976
#
# [103 rows x 6 columns]

# %%
-0.044661*100 # percent change from 14-Sep to 15-Sep is ~ 4%
# Out:
# -4.4661

# %%
arm_df.pct_change().describe()
# Out:
#              Open        High         Low       Close   Adj Close      Volume
# count  102.000000  102.000000  102.000000  102.000000  102.000000  102.000000
# mean     0.007586    0.007644    0.006870    0.007246    0.007246    0.153801
# std      0.053399    0.071382    0.043914    0.057976    0.057976    0.807762
# min     -0.155617   -0.148681   -0.094321   -0.082840   -0.082840   -0.622475
# 25%     -0.021446   -0.012805   -0.013490   -0.019372   -0.019372   -0.294645
# 50%      0.004127    0.001546    0.003885   -0.001232   -0.001232   -0.095376
# 75%      0.027623    0.018615    0.020770    0.026885    0.026885    0.326215
# max      0.292049    0.628941    0.301038    0.478899    0.478899    4.988245

# %%
0.057976*100 # std ~5% per day
# Out:
# 5.7976

# %%
-0.082840*100 # we may loss ~8% per day
# Out:
# -8.283999999999999

# %%
arm_df.pct_change().describe()*100 # we normally don't directly multiply these statistics data by 100 as we can see the number of count wil be change to wrong one
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  10200.000000  10200.000000  10200.000000  10200.000000  10200.000000
# mean       0.758595      0.764383      0.686979      0.724617      0.724617
# std        5.339946      7.138186      4.391375      5.797642      5.797642
# min      -15.561703    -14.868114     -9.432098     -8.283983     -8.283983
# 25%       -2.144603     -1.280533     -1.348994     -1.937186     -1.937186
# 50%        0.412744      0.154595      0.388515     -0.123170     -0.123170
# 75%        2.762317      1.861516      2.077003      2.688543      2.688543
# max       29.204878     62.894094     30.103806     47.889880     47.889880
#
#              Volume
# count  10200.000000
# mean      15.380080
# std       80.776220
# min      -62.247550
# 25%      -29.464485
# 50%       -9.537634
# 75%       32.621528
# max      498.824504

# %%
arm_df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2023-09-14  56.099998  66.279999  55.540001  63.590000  63.590000  130534500
# 2023-09-15  68.629997  69.000000  60.750000  60.750000  60.750000   74568900
# 2023-09-18  57.950001  58.741001  55.020000  58.000000  58.000000   34571900
# 2023-09-19  56.250000  56.779999  53.880001  55.169998  55.169998   18308600
# 2023-09-20  55.169998  55.400002  51.520000  52.910000  52.910000   16369500

# %%
arm_df.pct_change(5) # change by 5 days - a week change
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2023-09-14       NaN       NaN       NaN       NaN        NaN        NaN
# 2023-09-15       NaN       NaN       NaN       NaN        NaN        NaN
# 2023-09-18       NaN       NaN       NaN       NaN        NaN        NaN
# 2023-09-19       NaN       NaN       NaN       NaN        NaN        NaN
# 2023-09-20       NaN       NaN       NaN       NaN        NaN        NaN
# ...              ...       ...       ...       ...        ...        ...
# 2024-02-05 -0.000139  0.018232  0.005618  0.004662   0.004662   0.680855
# 2024-02-06  0.020436  0.017532  0.013409  0.014034   0.014034   0.700809
# 2024-02-07  0.034107  0.071271  0.037776  0.089713   0.089713   3.482299
# 2024-02-08  0.313622  0.744797  0.356030  0.615003   0.615003  29.639423
# 2024-02-09  0.490717  0.637526  0.458429  0.622676   0.622676  10.223242
#
# [103 rows x 6 columns]

# %%
arm_df.pct_change(5).describe()
# Out:
#             Open       High        Low      Close  Adj Close     Volume
# count  98.000000  98.000000  98.000000  98.000000  98.000000  98.000000
# mean    0.021439   0.026782   0.023268   0.026599   0.026599   0.555916
# std     0.087860   0.119929   0.086047   0.108638   0.108638   3.242947
# min    -0.229200  -0.233333  -0.171111  -0.179745  -0.179745  -0.886948
# 25%    -0.035640  -0.039261  -0.029763  -0.036349  -0.036349  -0.393359
# 50%     0.020635   0.012115   0.019264   0.016449   0.016449  -0.119710
# 75%     0.062560   0.068545   0.069590   0.061131   0.061131   0.605179
# max     0.490717   0.744797   0.458429   0.622676   0.622676  29.639423

# %%
arm_df.pct_change(21).describe() # monthly check - average 21 days
# Out:
#             Open       High        Low      Close  Adj Close     Volume
# count  82.000000  82.000000  82.000000  82.000000  82.000000  82.000000
# mean    0.092912   0.098975   0.095938   0.098949   0.098949   0.431534
# std     0.132851   0.155554   0.128356   0.147473   0.147473   2.068598
# min    -0.256302  -0.241304  -0.159835  -0.201447  -0.201447  -0.955520
# 25%    -0.014754  -0.011238  -0.001595  -0.016426  -0.016426  -0.427909
# 50%     0.079010   0.071112   0.084962   0.073280   0.073280   0.029530
# 75%     0.191927   0.209054   0.207864   0.204175   0.204175   0.595672
# max     0.451918   0.734516   0.461351   0.627950   0.627950  16.804363
