# %%
import pandas as pd

# %%
parks = pd.read_csv('data_us_national_parks/parks.csv')
parks.head()
# Out:
#   Park Code               Park Name State   Acres  Latitude  Longitude
# 0      ACAD    Acadia National Park    ME   47390     44.35     -68.21
# 1      ARCH    Arches National Park    UT   76519     38.68    -109.57
# 2      BADL  Badlands National Park    SD  242756     43.75    -102.50
# 3      BIBE  Big Bend National Park    TX  801163     29.25    -103.25
# 4      BISC  Biscayne National Park    FL  172924     25.65     -80.08

# %%
parks.shape
# Out:
# (56, 6)

# %%
species = pd.read_csv('data_us_national_parks/species.csv', low_memory = False)
species.head()
# Out:
#   Species ID             Park Name Category         Order    Family  \
# 0  ACAD-1000  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 1  ACAD-1001  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 2  ACAD-1002  Acadia National Park   Mammal     Carnivora   Canidae
# 3  ACAD-1003  Acadia National Park   Mammal     Carnivora   Canidae
# 4  ACAD-1004  Acadia National Park   Mammal     Carnivora   Canidae
#
#           Scientific Name                                       Common Names  \
# 0             Alces alces                                              Moose
# 1  Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2           Canis latrans                             Coyote, Eastern Coyote
# 3             Canis lupus        Eastern Timber Wolf, Gray Wolf, Timber Wolf
# 4           Vulpes vulpes  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...
#
#   Record Status     Occurrence  Nativeness Abundance Seasonality  \
# ...

# %%
species.shape
# Out:
# (119248, 14)

# %%
parks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Park Code  56 non-null     object
#  1   Park Name  56 non-null     object
#  2   State      56 non-null     object
#  3   Acres      56 non-null     int64
#  4   Latitude   56 non-null     float64
#  5   Longitude  56 non-null     float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 2.8+ KB

# %%
species.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119248 entries, 0 to 119247
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Species ID           119248 non-null  object
#  1   Park Name            119248 non-null  object
#  2   Category             119248 non-null  object
#  3   Order                117776 non-null  object
#  4   Family               117736 non-null  object
#  5   Scientific Name      119248 non-null  object
#  6   Common Names         119248 non-null  object
#  7   Record Status        119248 non-null  object
#  8   Occurrence           99106 non-null   object
#  9   Nativeness           94203 non-null   object
#  10  Abundance            76306 non-null   object
#  11  Seasonality          20157 non-null   object
#  12  Conservation Status  4718 non-null    object
#  13  Unnamed: 13          5 non-null       object
# dtypes: object(14)
# memory usage: 12.7+ MB

# %%
species['Species ID'].unique()
# Out:
# array(['ACAD-1000', 'ACAD-1001', 'ACAD-1002', ..., 'ZION-2793',
#        'ZION-2794', 'ZION-2795'], dtype=object)

# %%
def first_four(long_string):
    return long_string[0:4]

# %%
species['specie_park_code'] = species['Species ID'].apply(first_four)
species.tail()
# Out:
#        Species ID           Park Name        Category          Order  \
# 119243  ZION-2791  Zion National Park  Vascular Plant      Solanales
# 119244  ZION-2792  Zion National Park  Vascular Plant        Vitales
# 119245  ZION-2793  Zion National Park  Vascular Plant        Vitales
# 119246  ZION-2794  Zion National Park  Vascular Plant  Zygophyllales
# 119247  ZION-2795  Zion National Park  Vascular Plant  Zygophyllales
#
#                 Family      Scientific Name         Common Names  \
# 119243      Solanaceae    Solanum triflorum  Cut-Leaf Nightshade
# 119244        Vitaceae      Vitis arizonica         Canyon Grape
# 119245        Vitaceae       Vitis vinifera           Wine Grape
# 119246  Zygophyllaceae    Larrea tridentata        Creosote Bush
# 119247  Zygophyllaceae  Tribulus terrestris        Puncture Vine
#
#        Record Status Occurrence  Nativeness Abundance Seasonality  \
# 119243      Approved    Present      Native  Uncommon         NaN
# ...

# %%
species.shape
# Out:
# (119248, 15)

# %%
species.specie_park_code.unique()
# Out:
# array(['ACAD', 'ARCH', 'BADL', 'BIBE', 'BISC', 'BLCA', 'BRCA', 'CANY',
#        'CARE', 'CAVE', 'CHIS', 'CONG', 'CRLA', 'CUVA', 'DENA', 'DEVA',
#        'DRTO', 'EVER', 'GAAR', 'GLAC', 'GLBA', 'GRBA', 'GRCA', 'GRSA',
#        'GRSM', 'GRTE', 'GUMO', 'HALE', 'HAVO', 'HOSP', 'ISRO', 'JOTR',
#        'KATM', 'KEFJ', 'KOVA', 'LACL', 'LAVO', 'MACA', 'MEVE', 'MORA',
#        'NOCA', 'OLYM', 'PEFO', 'PINN', 'REDW', 'ROMO', 'SAGU', 'SEKI',
#        'SHEN', 'THRO', 'VOYA', 'WICA', 'WRST', 'YELL', 'YOSE', 'ZION'],
#       dtype=object)

# %%
del species['Unnamed: 13']

# %%
species.shape
# Out:
# (119248, 14)

# %%
species.tail()
# Out:
#        Species ID           Park Name        Category          Order  \
# 119243  ZION-2791  Zion National Park  Vascular Plant      Solanales
# 119244  ZION-2792  Zion National Park  Vascular Plant        Vitales
# 119245  ZION-2793  Zion National Park  Vascular Plant        Vitales
# 119246  ZION-2794  Zion National Park  Vascular Plant  Zygophyllales
# 119247  ZION-2795  Zion National Park  Vascular Plant  Zygophyllales
#
#                 Family      Scientific Name         Common Names  \
# 119243      Solanaceae    Solanum triflorum  Cut-Leaf Nightshade
# 119244        Vitaceae      Vitis arizonica         Canyon Grape
# 119245        Vitaceae       Vitis vinifera           Wine Grape
# 119246  Zygophyllaceae    Larrea tridentata        Creosote Bush
# 119247  Zygophyllaceae  Tribulus terrestris        Puncture Vine
#
#        Record Status Occurrence  Nativeness Abundance Seasonality  \
# 119243      Approved    Present      Native  Uncommon         NaN
# ...

# %%
species.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119248 entries, 0 to 119247
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Species ID           119248 non-null  object
#  1   Park Name            119248 non-null  object
#  2   Category             119248 non-null  object
#  3   Order                117776 non-null  object
#  4   Family               117736 non-null  object
#  5   Scientific Name      119248 non-null  object
#  6   Common Names         119248 non-null  object
#  7   Record Status        119248 non-null  object
#  8   Occurrence           99106 non-null   object
#  9   Nativeness           94203 non-null   object
#  10  Abundance            76306 non-null   object
#  11  Seasonality          20157 non-null   object
#  12  Conservation Status  4718 non-null    object
#  13  specie_park_code     119248 non-null  object
# dtypes: object(14)
# memory usage: 12.7+ MB

# %%
parks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Park Code  56 non-null     object
#  1   Park Name  56 non-null     object
#  2   State      56 non-null     object
#  3   Acres      56 non-null     int64
#  4   Latitude   56 non-null     float64
#  5   Longitude  56 non-null     float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 2.8+ KB

# %%
final_df = parks.merge(species, how = 'left', left_on = 'Park Code', right_on = 'specie_park_code')
final_df.head()
# Out:
#   Park Code           Park Name_x State  Acres  Latitude  Longitude  \
# 0      ACAD  Acadia National Park    ME  47390     44.35     -68.21
# 1      ACAD  Acadia National Park    ME  47390     44.35     -68.21
# 2      ACAD  Acadia National Park    ME  47390     44.35     -68.21
# 3      ACAD  Acadia National Park    ME  47390     44.35     -68.21
# 4      ACAD  Acadia National Park    ME  47390     44.35     -68.21
#
#   Species ID           Park Name_y Category         Order    Family  \
# 0  ACAD-1000  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 1  ACAD-1001  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 2  ACAD-1002  Acadia National Park   Mammal     Carnivora   Canidae
# 3  ACAD-1003  Acadia National Park   Mammal     Carnivora   Canidae
# 4  ACAD-1004  Acadia National Park   Mammal     Carnivora   Canidae
#
#           Scientific Name                                       Common Names  \
# ...

# %%
final_df.shape
# Out:
# (119248, 20)
