# %% [markdown]
# ### Basic Plot - Heart
#
# - Learn from Aj. Prasert CBS
# - YouTube: https://www.youtube.com/prasertcbs

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('yEglNbmJJ8w', width = 720, height = 405)

# %%
# import libraries 

import matplotlib.pyplot as plt
import numpy as np 

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
x = np.linspace(0, 360, 180) # degree
x
# Out:
# array([  0.        ,   2.01117318,   4.02234637,   6.03351955,
#          8.04469274,  10.05586592,  12.06703911,  14.07821229,
#         16.08938547,  18.10055866,  20.11173184,  22.12290503,
#         24.13407821,  26.1452514 ,  28.15642458,  30.16759777,
#         32.17877095,  34.18994413,  36.20111732,  38.2122905 ,
#         40.22346369,  42.23463687,  44.24581006,  46.25698324,
#         48.26815642,  50.27932961,  52.29050279,  54.30167598,
#         56.31284916,  58.32402235,  60.33519553,  62.34636872,
#         64.3575419 ,  66.36871508,  68.37988827,  70.39106145,
#         72.40223464,  74.41340782,  76.42458101,  78.43575419,
#         80.44692737,  82.45810056,  84.46927374,  86.48044693,
#         88.49162011,  90.5027933 ,  92.51396648,  94.52513966,
#         96.53631285,  98.54748603, 100.55865922, 102.5698324 ,
#        104.58100559, 106.59217877, 108.60335196, 110.61452514,
#        112.62569832, 114.63687151, 116.64804469, 118.65921788,
# ...

# %%
x = np.linspace(0, 360 + 1, 180) # degree
x
# Out:
# array([  0.        ,   2.01675978,   4.03351955,   6.05027933,
#          8.06703911,  10.08379888,  12.10055866,  14.11731844,
#         16.13407821,  18.15083799,  20.16759777,  22.18435754,
#         24.20111732,  26.21787709,  28.23463687,  30.25139665,
#         32.26815642,  34.2849162 ,  36.30167598,  38.31843575,
#         40.33519553,  42.35195531,  44.36871508,  46.38547486,
#         48.40223464,  50.41899441,  52.43575419,  54.45251397,
#         56.46927374,  58.48603352,  60.5027933 ,  62.51955307,
#         64.53631285,  66.55307263,  68.5698324 ,  70.58659218,
#         72.60335196,  74.62011173,  76.63687151,  78.65363128,
#         80.67039106,  82.68715084,  84.70391061,  86.72067039,
#         88.73743017,  90.75418994,  92.77094972,  94.7877095 ,
#         96.80446927,  98.82122905, 100.83798883, 102.8547486 ,
#        104.87150838, 106.88826816, 108.90502793, 110.92178771,
#        112.93854749, 114.95530726, 116.97206704, 118.98882682,
# ...

# %%
x = np.linspace(0, 360 + 1, 180) # degree
y = np.sin(np.radians(x)) # radians
y2 = np.cos(np.radians(x))

plt.figure(figsize = (14, 7))
plt.plot(x, y, label = 'sin', color = 'orange')
plt.plot(x, y2, label = 'cos', color = 'blue')

plt.legend()
plt.axhline(0, color = '.7', linestyle = '--')

# %%
x = np.linspace(0, 360 + 1, 180) # degree
y = np.sin(np.radians(x)) # radians
y2 = np.cos(np.radians(x))

plt.figure(figsize = (14, 7))
plt.plot(x, y, label = 'sin', color = 'orange')
plt.plot(x, y2, label = 'cos', color = 'blue')

plt.legend(fontsize = 15)
plt.xticks(np.arange(0, 360 + 1, 45), fontsize = 20, color = 'red')
plt.axhline(0, color = '.7', linestyle = '--')

vlines = np.arange(0, 360 + 1, 45)
for   v in vlines:
    plt.axvline(v, color = '.8', linestyle = '--')

# %%
x = np.linspace(0, 360 + 1, 180) # degree
y = np.sin(np.radians(x)) # radians
y2 = np.cos(np.radians(x))

plt.figure(figsize = (14, 7))
plt.plot(x, y, label = 'sin', color = 'orange')
plt.plot(x, y2, label = 'cos', color = 'blue')

plt.legend(fontsize = 20)
# plt.xticks(np.arange(0, 360 + 1, step = 90))
plt.xticks(np.arange(0, 360 + 1, step = 90), ['0', r'$\frac{\pi}{2}$', r'$\pi$', r'$\frac{3\pi}{2}$', r'$2\pi$'], fontsize = 20, color = 'red')
plt.axhline(0, color = '.7', linestyle = '--')
plt.yticks(fontsize = 15)

vlines = np.arange(0, 360 + 1, 45)
for   v in vlines:
    plt.axvline(v, color = '.8', linestyle = '--')
