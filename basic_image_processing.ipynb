# %%
# !pip install pillow

# %% [markdown]
# ### Image processing
# - read images and get a lot of information about it

# %%
from PIL import Image # import image module

# %%
wheel = Image.open('pics/wheel.jpg') # to get wheel object

# %%
type(wheel)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
wheel
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2048x1536>

# %%
wheel.size
# Out:
# (2048, 1536)

# %%
# wheel.jpg has 2048x1536 pixel

# %%
wheel.filename
# Out:
# 'pics/wheel.jpg'

# %%
wheel.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
# we can google it to understand what is JPEG (ISO 10918)
