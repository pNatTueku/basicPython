# %%
# import libraries

import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average'

pd.read_html(url)
# Out:
# [                                                   0  \
#  0  Historical logarithmic graph of the DJIA from ...
#  1                                         Foundation
#  2                                           Operator
#  3                                          Exchanges
#  4                                     Trading symbol
#  5                                       Constituents
#  6                                               Type
#  7                                         Market cap
#  8                                   Weighting method
#  9                                            Website
#
#                                                     1
#  0  Historical logarithmic graph of the DJIA from ...
#  1  February 16, 1885; 139 years ago[1] May 26, 18...
#  2                              S&P Dow Jones Indices
#  3  .mw-parser-output .plainlist ol,.mw-parser-out...
#  4                                  ^DJI$INDU.DJIDJIA
# ...

# %%
pd.read_html(url)[0]
# Out:
#                                                    0  \
# 0  Historical logarithmic graph of the DJIA from ...
# 1                                         Foundation
# 2                                           Operator
# 3                                          Exchanges
# 4                                     Trading symbol
# 5                                       Constituents
# 6                                               Type
# 7                                         Market cap
# 8                                   Weighting method
# 9                                            Website
#
#                                                    1
# 0  Historical logarithmic graph of the DJIA from ...
# 1  February 16, 1885; 139 years ago[1] May 26, 18...
# 2                              S&P Dow Jones Indices
# 3  .mw-parser-output .plainlist ol,.mw-parser-out...
# 4                                  ^DJI$INDU.DJIDJIA
# 5                                                 30
# ...

# %%
pd.read_html(url)[1]
# Out:
#                      Company Exchange Symbol                        Industry  \
# 0                         3M     NYSE    MMM                    Conglomerate
# 1           American Express     NYSE    AXP              Financial services
# 2                      Amgen   NASDAQ   AMGN               Biopharmaceutical
# 3                      Apple   NASDAQ   AAPL          Information technology
# 4                     Boeing     NYSE     BA           Aerospace and defense
# 5                Caterpillar     NYSE    CAT         Construction and mining
# 6                    Chevron     NYSE    CVX              Petroleum industry
# 7                      Cisco   NASDAQ   CSCO          Information technology
# 8                  Coca-Cola     NYSE     KO                  Drink industry
# 9                     Disney     NYSE    DIS  Broadcasting and entertainment
# 10                       Dow     NYSE    DOW               Chemical industry
# ...

# %%
pd.read_html(url)[2]
# Out:
#      Year  Closing Value Net Change % Change
# 0    1896          40.45      −0.49    −1.20
# 1    1897          49.41      +8.96   +22.15
# 2    1898          60.52     +11.11   +22.49
# 3    1899          66.08      +5.56    +9.19
# 4    1900          70.71      +4.63    +7.01
# ..    ...            ...        ...      ...
# 123  2019       28538.44   +5210.98   +22.34
# 124  2020       30606.48   +2068.04    +7.25
# 125  2021       36338.30   +5731.82   +18.73
# 126  2022       33147.25  −3,191.05    −8.78
# 127  2023       37689.54   +4542.29   +13.70
#
# [128 rows x 4 columns]

# %%
pd.read_html(url)[4]
# Out:
#   vteMajor North and South American stock market indices  \
# 0                                      United States
# 1                                             Canada
# 2                                             Mexico
# 3                                           Colombia
# 4                                             Brazil
# 5                                              Chile
# 6                                          Argentina
# 7                                               Peru
#
#   vteMajor North and South American stock market indices.1
# 0  Dow Jones Industrial Average Dow Jones Transpo...
# 1                 S&P/TSX 60 S&P/TSX Composite Index
# 2                   Indice de Precios y Cotizaciones
# 3  COLCAP Indice General de la Bolsa de Valores d...
# 4                                     Índice Bovespa
# 5             Índice de Precio Selectivo de Acciones
# 6                                             MERVAL
# ...

# %%
pd.read_html(url)[-1]
# Out:
#   Authority control databases                 Authority control databases.1
# 0               International                                          FAST
# 1                    National  France BnF data Germany Israel United States

# %%
stock_symbol_list = pd.read_html(url)[1]
stock_symbol_list.head()
# Out:
#             Company Exchange Symbol                Industry  Date added  \
# 0                3M     NYSE    MMM            Conglomerate  1976-08-09
# 1  American Express     NYSE    AXP      Financial services  1982-08-30
# 2             Amgen   NASDAQ   AMGN       Biopharmaceutical  2020-08-31
# 3             Apple   NASDAQ   AAPL  Information technology  2015-03-19
# 4            Boeing     NYSE     BA   Aerospace and defense  1987-03-12
#
#                                    Notes Index weighting
# 0  As Minnesota Mining and Manufacturing           2.41%
# 1                                    NaN           3.02%
# 2                                    NaN           5.48%
# 3                                    NaN           2.84%
# 4                                    NaN           3.36%

# %%
stock_symbol_list.shape
# Out:
# (30, 7)

# %%
stock_symbol_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Company          30 non-null     object
#  1   Exchange         30 non-null     object
#  2   Symbol           30 non-null     object
#  3   Industry         30 non-null     object
#  4   Date added       30 non-null     object
#  5   Notes            5 non-null      object
#  6   Index weighting  30 non-null     object
# dtypes: object(7)
# memory usage: 1.8+ KB

# %%
stock_symbol_list.Symbol
# Out:
# 0      MMM
# 1      AXP
# 2     AMGN
# 3     AAPL
# 4       BA
# 5      CAT
# 6      CVX
# 7     CSCO
# 8       KO
# 9      DIS
# 10     DOW
# 11      GS
# 12      HD
# 13     HON
# 14     IBM
# 15    INTC
# 16     JNJ
# 17     JPM
# 18     MCD
# 19     MRK
# 20    MSFT
# 21     NKE
# 22      PG
# 23     CRM
# 24     TRV
# 25     UNH
# 26      VZ
# 27       V
# 28     WBA
# 29     WMT
# Name: Symbol, dtype: object

# %%
stock_symbol_list['Symbol'].values
# Out:
# array(['MMM', 'AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CVX', 'CSCO', 'KO',
#        'DIS', 'DOW', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'JPM',
#        'MCD', 'MRK', 'MSFT', 'NKE', 'PG', 'CRM', 'TRV', 'UNH', 'VZ', 'V',
#        'WBA', 'WMT'], dtype=object)

# %%
import yfinance as yf

# %%
for symbol in stock_symbol_list['Symbol'].values:

    df = yf.download(symbol, progress = False) # download and save each symbol in the list
    df.to_csv(f'Data/DWJ_download/{symbol}.csv') # save to csv files
