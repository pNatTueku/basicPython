# %%
# import libraries

import numpy as np
import matplotlib.pyplot as plt

# %%
rn_default = np.random.default_rng()
rn_default
# Out:
# Generator(PCG64) at 0x114257040

# %%
rn_default.normal()
# Out:
# 0.05600179369560528

# %%
rn_default.normal()
# Out:
# 1.049948411587455

# %%
# with number of data

nums = rn_default.normal(size = 100)
nums
# Out:
# array([ 1.14516640e+00,  9.77315483e-01,  1.26603463e+00,  6.35184506e-01,
#        -1.22097895e+00, -8.77920721e-01,  7.98113501e-01,  5.74383749e-01,
#         3.15905002e-01, -2.76465098e+00,  5.69154090e-01, -2.82697067e-01,
#        -3.84077177e-02,  7.45246239e-01, -5.31919312e-01, -6.90295404e-02,
#         1.49311149e+00,  1.58722012e+00, -5.59005734e-01, -3.64373982e-01,
#        -1.20416428e-01, -1.04512340e+00, -9.28472793e-01,  8.62991967e-01,
#         1.64589294e+00, -2.33420425e-01, -2.44726356e-01, -8.23914354e-01,
#        -2.20061894e+00,  2.76902301e-01, -1.95862280e+00, -1.38887705e+00,
#        -9.10956703e-01, -7.55912279e-01, -1.24195009e+00,  4.07361630e-02,
#        -1.75056157e+00,  4.32762212e-01,  5.38371933e-01, -5.35225545e-02,
#        -7.44088552e-01, -2.00782066e+00,  4.12960679e-01,  5.03232862e-02,
#        -8.93498331e-01,  3.07278984e-01,  3.62890154e-01, -6.70053249e-01,
#        -8.29750131e-01, -1.13047057e+00,  4.41199770e-01, -2.90732938e-01,
#         5.04863492e-01, -9.40962335e-02,  4.64227821e-01,  7.38285189e-01,
#         1.61095916e+00, -5.06767728e-01, -1.42383400e+00,  3.46391879e-01,
#         1.09577613e+00,  1.87157170e-01,  1.04342648e+00, -2.43577164e+00,
#         5.63854218e-01,  4.36033269e-01, -8.18631643e-01, -5.35955988e-01,
#         7.08854201e-01,  1.14106823e+00,  2.08979425e-01, -1.89977871e+00,
#        -1.13760361e+00,  1.13543607e+00, -3.22241831e-01, -1.65119449e+00,
#        -1.23067673e-01, -5.15868603e-01,  1.63220340e+00,  8.88191470e-01,
#         2.61334463e+00, -1.40519067e+00,  1.54868285e+00,  1.05852652e-01,
#        -4.97222614e-01, -6.25695678e-02, -1.01774201e-01, -5.82989968e-01,
#         6.87365796e-03, -3.04332854e-01, -1.04945781e+00, -3.89329330e-01,
#         1.13197315e+00,  7.05017177e-01, -1.65943794e+00, -1.36658701e+00,
#         2.64075339e-03,  1.49091456e+00, -6.72954285e-01, -8.43085643e-01])

# %%
len(nums)
# Out:
# 100

# %%
nums = rn_default.normal(size = 10000)
len(nums)
# Out:
# 10000

# %%
nums.mean()
# Out:
# 0.007017332216064538

# %%
nums.std()
# Out:
# 1.0138279385899882

# %%
rn_default.normal(size = (2, 4)) # 2 dimensional 2 rows x 4 columns
# Out:
# array([[ 0.11897978,  1.81084626, -0.66881085,  1.08978434],
#        [ 0.87122737, -1.03301605,  0.48580811,  0.05975223]])

# %%
nums = rn_default.normal(size = 1000)
plt.hist(nums)
plt.show()

# %%
nums = rn_default.normal(size = 10000)
plt.hist(nums)
plt.show()

# %%
nums = rn_default.normal(size = 10000)
plt.hist(nums, bins = 50)
plt.show()
