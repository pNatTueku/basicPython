# %%
# import libraties

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt

# %matplotlib inline
sns.set_style('whitegrid')

# %%
# load csv file to a dataframe

df = pd.read_csv('Data/SET50_download_r2/ADVANC.BK.csv', index_col = 0)
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2000-01-04  44.599998  46.000000  43.000000  43.400002  11.032709  1039000
# 2000-01-05  38.200001  41.000000  38.000000  40.599998  10.320922  2624000
# 2000-01-06  41.000000  41.200001  38.400002  38.599998   9.812499  1341000
# 2000-01-07  38.599998  39.799999  38.000000  38.599998   9.812499  1164000
# 2000-01-10  39.799999  40.799999  39.599998  40.000000  10.168396   761000

# %%
df.index
# Out:
# Index(['2000-01-04', '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-10',
#        '2000-01-11', '2000-01-12', '2000-01-13', '2000-01-14', '2000-01-17',
#        ...
#        '2024-02-12', '2024-02-13', '2024-02-14', '2024-02-15', '2024-02-16',
#        '2024-02-19', '2024-02-20', '2024-02-21', '2024-02-22', '2024-02-23'],
#       dtype='object', name='Date', length=5994)

# %%
# set index from object to datetime

df.set_index(pd.to_datetime(df.index), inplace = True)
df.index
# Out:
# DatetimeIndex(['2000-01-04', '2000-01-05', '2000-01-06', '2000-01-07',
#                '2000-01-10', '2000-01-11', '2000-01-12', '2000-01-13',
#                '2000-01-14', '2000-01-17',
#                ...
#                '2024-02-12', '2024-02-13', '2024-02-14', '2024-02-15',
#                '2024-02-16', '2024-02-19', '2024-02-20', '2024-02-21',
#                '2024-02-22', '2024-02-23'],
#               dtype='datetime64[ns]', name='Date', length=5994, freq=None)

# %%
# get data from 2020

df = df['2020':]
df.head()
# Out:
#              Open   High    Low  Close   Adj Close   Volume
# Date
# 2020-01-02  214.0  219.0  212.0  218.0  183.957199  5921300
# 2020-01-03  216.0  217.0  215.0  216.0  182.269547  4426800
# 2020-01-06  216.0  220.0  216.0  217.0  183.113388  5147100
# 2020-01-07  218.0  224.0  217.0  223.0  188.176453  7220900
# 2020-01-08  221.0  223.0  219.0  220.0  185.644913  6768300

# %%
df.tail()
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2024-02-19  209.0  210.0  208.0  209.0      209.0   4822100
# 2024-02-20  210.0  210.0  207.0  207.0      207.0   4352500
# 2024-02-21  208.0  209.0  203.0  205.0      205.0  12475500
# 2024-02-22  205.0  211.0  204.0  209.0      209.0   9222400
# 2024-02-23  209.0  209.0  206.0  206.0      206.0   4196600

# %%
df.shape
# Out:
# (1006, 6)

# %% [markdown]
# ### Simple Return
#
# $$
# \frac{P_t}{P_{t-1}} - 1
# $$

# %%
# add new calculated column for simple return

df['simple_return'] = (df['Close']/df['Close'].shift(1)) - 1
df.head()
# Out:
#              Open   High    Low  Close   Adj Close   Volume  simple_return
# Date
# 2020-01-02  214.0  219.0  212.0  218.0  183.957199  5921300            NaN
# 2020-01-03  216.0  217.0  215.0  216.0  182.269547  4426800      -0.009174
# 2020-01-06  216.0  220.0  216.0  217.0  183.113388  5147100       0.004630
# 2020-01-07  218.0  224.0  217.0  223.0  188.176453  7220900       0.027650
# 2020-01-08  221.0  223.0  219.0  220.0  185.644913  6768300      -0.013453

# %%
216.0/218.0 - 1
# Out:
# -0.00917431192660545

# %%
# apply a build-in function to get simple return

df['Close'].pct_change().head()
# Out:
# Date
# 2020-01-02         NaN
# 2020-01-03   -0.009174
# 2020-01-06    0.004630
# 2020-01-07    0.027650
# 2020-01-08   -0.013453
# Name: Close, dtype: float64

# %%
# plot

plt.rcParams['figure.figsize'] = (10.0, 5.0)

df[['simple_return']].plot(linewidth = 2)
plt.xlabel('Date')
plt.ylabel('Percent Change')
plt.title('Simple Return of ADVANC.BK')
plt.show()

# %%
df['simple_return'].mean()
# Out:
# 2.78089765051957e-05

# %%
df['Close'].plot(); # plot

# %%
df['simple_return'].cumsum().plot(); # plot cumsum

# %% [markdown]
# ### Log Return
#
# $$
# ln(\frac{P_t}{P_{t-1}})
# $$

# %%
# add a new calculated column for log return


df['log_return'] = np.log(df['Close']/df['Close'].shift(1))
df.head()
# Out:
#              Open   High    Low  Close   Adj Close   Volume  simple_return  \
# Date
# 2020-01-02  214.0  219.0  212.0  218.0  183.957199  5921300            NaN
# 2020-01-03  216.0  217.0  215.0  216.0  182.269547  4426800      -0.009174
# 2020-01-06  216.0  220.0  216.0  217.0  183.113388  5147100       0.004630
# 2020-01-07  218.0  224.0  217.0  223.0  188.176453  7220900       0.027650
# 2020-01-08  221.0  223.0  219.0  220.0  185.644913  6768300      -0.013453
#
#             log_return
# Date
# 2020-01-02         NaN
# 2020-01-03   -0.009217
# 2020-01-06    0.004619
# 2020-01-07    0.027274
# 2020-01-08   -0.013544

# %%
np.log(216.0/218.0)
# Out:
# -0.009216655104923952

# %%
# plot

plt.rcParams['figure.figsize'] = (10.0, 5.0)

df[['log_return']].plot(linewidth = 2)
plt.xlabel('Date')
plt.ylabel('Percent Change')
plt.title('Log Return of ADVANC.BK')
plt.show()

# %%
df['log_return'].mean()
# Out:
# -5.6337207959711395e-05

# %%
# plot

plt.rcParams['figure.figsize'] = (10.0, 5.0)

df[['simple_return', 'log_return']].plot(linewidth = 2)
plt.xlabel('Date')
plt.ylabel('Percent Change')
plt.title('Simple&Log Return of ADVANC.BK')
plt.show()

# %%
# Annual Log Return

annual_log_return = df['log_return'].mean() * 252
annual_log_return
# Out:
# -0.01419697640584727

# %%
print(f'Annual Return: {(annual_log_return * 100):.4}%')
# Out:
# Annual Return: -1.42%

# %% [markdown]
# ### Randoms, Histogram, and Normal Distribution

# %%
np.random.seed(20)

mu = 0
sigma = 0.05

# %%
stock_1 = np.random.normal(mu, sigma, 10000) # random numbers
stock_1
# Out:
# array([ 0.04419466,  0.00979325,  0.01787683, ..., -0.04157543,
#        -0.06966699, -0.05317517])

# %%
plt.rcParams['figure.figsize'] = (10.0, 5.0)

plt.plot(stock_1.cumsum())

# %%
sns.histplot(stock_1, bins = 100, color = 'green')
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
# load csv data to a dataframe

bdms = pd.read_csv('Data/SET50_download_r2/BDMS.BK.csv', index_col = 0)
bdms.set_index(pd.to_datetime(bdms.index), inplace = True)
bdms = bdms['2013': '2023']
bdms.head()
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2013-01-02  11.50  11.50  11.30  11.30   9.314999  19474000
# 2013-01-03  11.35  11.45  11.35  11.45   9.438648  25001000
# 2013-01-04  11.45  11.50  11.35  11.50   9.479865  22793000
# 2013-01-07  11.55  11.60  11.40  11.40   9.397430  27909000
# 2013-01-08  11.40  11.55  11.40  11.50   9.479865  15006000

# %%
bdms.tail()
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2023-12-22  26.25  26.75  26.00  26.25      26.25  65617700
# 2023-12-25  26.25  26.75  26.25  26.75      26.75  15755500
# 2023-12-26  26.75  27.75  26.75  27.50      27.50  65852500
# 2023-12-27  27.50  27.75  27.25  27.75      27.75  39174500
# 2023-12-28  27.50  28.00  27.25  27.75      27.75  44815400

# %%
sns.histplot(bdms['Close'], bins = 100, color = '#80BCBD')
# Out:
# <AxesSubplot: xlabel='Close', ylabel='Count'>

# %%
bdms_pct = bdms['Close'].pct_change()
bdms_pct
# Out:
# Date
# 2013-01-02         NaN
# 2013-01-03    0.013274
# 2013-01-04    0.004367
# 2013-01-07   -0.008696
# 2013-01-08    0.008772
#                 ...
# 2023-12-22    0.009615
# 2023-12-25    0.019048
# 2023-12-26    0.028037
# 2023-12-27    0.009091
# 2023-12-28    0.000000
# Name: Close, Length: 2677, dtype: float64

# %%
bdms_pct = bdms_pct.dropna()
bdms_pct
# Out:
# Date
# 2013-01-03    0.013274
# 2013-01-04    0.004367
# 2013-01-07   -0.008696
# 2013-01-08    0.008772
# 2013-01-09   -0.004348
#                 ...
# 2023-12-22    0.009615
# 2023-12-25    0.019048
# 2023-12-26    0.028037
# 2023-12-27    0.009091
# 2023-12-28    0.000000
# Name: Close, Length: 2676, dtype: float64

# %%
# setting

mu_bdms = bdms_pct.mean()
sigma_bdms = bdms_pct.std()

stock_bdms = np.random.normal(mu_bdms, sigma_bdms, bdms_pct.shape[0])
stock_bdms
# Out:
# array([-0.0040874 , -0.00073886,  0.00311005, ..., -0.00084093,
#         0.00351513, -0.02520514])

# %%
stock_bdms.shape
# Out:
# (2676,)

# %%
# plots

sns.histplot(bdms_pct, color = '#80BCBD', bins = 50) # pastel grren 
sns.histplot(stock_bdms, bins = 50, color = '#F9F7C9') # pastel yellow
plt.show()

# %% [markdown]
# ### Mean

# %%
numbers = (1, 3, 5, 7, 9, 2, 4)
numbers
# Out:
# (1, 3, 5, 7, 9, 2, 4)

# %%
n = len(numbers)
n
# Out:
# 7

# %%
mean = np.sum(numbers)/n
mean
# Out:
# 4.428571428571429

# %%
# apply numpy function

np.mean(numbers)
# Out:
# 4.428571428571429

# %%
# calculate mean of bdms_pct

bdms_pct.mean()
# Out:
# 0.0004614288408716415

# %%
# plot mean

plt.rcParams['figure.figsize'] = (10.0, 8.0)

sns.histplot(stock_bdms, color = '#F9F7C9', bins = 50, kde = True)

plt.axvline(np.mean(stock_bdms), color = 'Blue', linewidth = 2)
print(f'Stock BDMS mean: {np.mean(stock_bdms):.4}%')
# Out:
# Stock BDMS mean: 0.000439%

# %% [markdown]
# ### Median

# %%
numbers = (1, 3, 5, 7, 9, 2, 4) # sorted 1, 2, 3, 4, 5, 7, 9
np.median(numbers)
# Out:
# 4.0

# %%
sns.histplot(stock_bdms, color='#F9F7C9', bins = 100, kde = True)
plt.axvline(np.mean(stock_bdms), color = 'Blue', linewidth = 2)
plt.axvline(np.median(stock_bdms), color = 'Green', linewidth = 2)
print(f'Mean: { np.round(np.mean(stock_bdms), 5)}%')
print(f'Median: { np.round(np.median(stock_bdms), 5)}%')
# Out:
# Mean: 0.00044%
# Median: 0.00039%

# %% [markdown]
# ### Skew
#
# - Mean > Median --> Skew to the right
# - Mean < Median --> Skew to the left

# %%
from scipy.stats import skewnorm

# %%
stock_a = skewnorm.rvs(10, size = 1000)
stock_a
# Out:
# array([ 9.05572454e-01,  1.68870991e+00,  1.48338929e+00,  6.59983793e-01,
#         1.09049308e+00,  3.80311914e-01,  9.94171342e-01,  1.40383434e+00,
#         3.44697040e-01,  1.94117847e+00,  3.12536436e-01,  4.84039454e-01,
#         2.35553377e+00,  5.80087282e-01,  1.10809311e+00,  2.32110187e-01,
#         1.79288865e+00,  3.54234897e-01,  4.95129898e-01,  9.07158894e-01,
#         1.41518395e-01,  7.73628148e-02,  1.84644577e-01,  1.86909788e-01,
#         1.05048204e+00,  1.76925270e+00,  6.98572213e-01,  2.63647113e-01,
#        -1.62833653e-03,  5.45252069e-01, -1.92530805e-02,  5.25160409e-01,
#         8.25279889e-01,  1.07149623e+00,  9.34365191e-01,  4.89570077e-01,
#         9.55288414e-01,  3.17874061e-01,  3.47268648e-02,  1.73832183e-02,
#         2.40078671e+00,  9.20320741e-01,  1.65821886e+00,  5.98066857e-01,
#         1.30405217e+00,  2.82539184e-01,  6.01465194e-01,  3.86012480e-01,
#         1.57604060e+00,  4.67947085e-01,  7.97999039e-01,  1.14436302e+00,
#         1.62651729e+00,  1.60696937e-01,  6.72189572e-01,  1.30785870e+00,
#         1.81866589e+00,  3.91763807e-01,  6.03414545e-01,  6.36445584e-01,
#        -1.54201027e-01,  1.73245823e+00,  2.50583227e+00,  8.15543578e-02,
#         1.38195930e+00,  7.96918217e-01,  1.71347184e-01,  5.11741117e-01,
#         9.02719845e-01,  4.00635157e-01,  3.09062942e+00,  4.91990222e-01,
#         1.29063730e+00,  1.24399102e+00,  1.17812045e-01,  1.22528179e-01,
#         8.05810406e-01,  8.95228860e-01,  1.72579426e+00,  1.09277857e+00,
#         1.46861588e-01,  6.54747767e-01,  9.40479740e-01,  6.09864473e-01,
#         7.38299901e-01,  7.58237014e-01,  6.33005582e-01,  1.64790319e-01,
#         4.23080894e-01, -9.75743076e-03,  9.03205722e-01,  1.88793664e-02,
#         1.42071216e+00,  1.07463408e+00,  6.22783150e-01,  1.65404279e+00,
#         1.26699632e+00,  2.02183671e+00,  5.71709933e-01,  5.28972849e-01,
#         2.53449982e-01,  5.94700318e-01,  4.85399088e-01,  3.40287558e-01,
#         1.59487359e+00,  3.68366400e-01,  1.09329218e+00,  8.38308397e-01,
#         4.26187394e-01,  3.14228540e-02,  8.45719819e-01,  1.58998999e-02,
#         5.80081577e-01,  7.22551605e-01,  5.90660882e-01,  1.83210386e-01,
#         1.05376382e+00,  5.40638909e-01,  8.34348760e-01,  9.01662631e-01,
#         1.66063222e+00,  1.30696349e+00,  6.24108806e-01,  9.84562343e-01,
#         1.23371007e-01,  9.32577743e-02,  6.49141004e-01,  2.18726368e+00,
#         7.84672516e-01,  8.88688646e-01,  6.35869728e-01,  1.50497311e+00,
#         1.01916996e+00,  5.14886072e-02,  1.30030089e+00,  6.27495842e-01,
#         2.40728493e+00,  7.11312130e-01,  3.80378052e-01,  2.80318010e-01,
#         8.16805943e-01,  6.64988119e-01,  2.91553553e-01,  7.88228436e-01,
#         3.91477923e-01,  5.14452875e-01,  5.86141730e-02,  3.61542800e-01,
#         1.68516742e+00,  1.78304087e+00,  5.68920354e-01,  3.28623172e-01,
#         4.98364793e-01,  2.16636876e+00,  2.00659588e+00,  1.46285020e+00,
#         3.28109016e-02,  1.20301158e+00, -2.09530037e-03,  5.68962238e-01,
#         8.47775662e-01,  2.06356004e-01,  1.34670213e+00,  2.05176728e-01,
#         7.06291943e-01,  1.43950091e+00,  1.12735654e+00,  4.42960162e-01,
#         2.18820531e+00,  6.48982760e-01,  1.20288531e+00, -1.37357063e-02,
#         4.60426719e-01,  1.79423890e+00,  7.09649182e-01,  1.51035341e-01,
#         8.40603927e-01,  3.81410085e-01,  1.14402499e+00,  8.96474852e-01,
#         3.45112746e-01,  8.35150953e-01,  5.11568491e-01,  3.73017019e-01,
#         8.90263153e-01,  6.96266512e-01,  1.42864493e+00,  1.50913574e+00,
#         1.22292562e+00,  1.15192916e+00,  4.28663766e-01,  7.71182820e-01,
#         1.84165603e-01,  2.62813987e-01,  5.24742250e-01,  3.39826429e-01,
#         1.51322995e+00,  2.05540914e-01,  5.97127911e-01,  7.16897840e-01,
#         8.36839953e-01,  1.36572849e+00,  2.37797698e+00,  1.81328235e+00,
#         2.58403539e-01,  4.13589468e-01,  4.42837793e-01,  4.44775873e-01,
#         1.52854175e+00,  1.08420816e+00,  2.04674980e+00,  7.10789509e-01,
#         1.65189420e-01,  1.86440579e-01,  2.04388292e-01,  4.38758330e-01,
#         2.12062140e-01,  4.75261326e-01,  1.34117021e+00,  8.05960086e-01,
#         6.44536326e-01,  2.65536270e+00,  8.56172208e-01,  2.03783730e+00,
#         9.61727075e-01,  7.45019814e-01,  3.65853106e-01,  8.57226454e-01,
#         1.02543948e+00,  7.18573520e-01,  6.07606681e-01,  4.89291271e-01,
#         1.34885706e+00,  4.18544070e-01,  8.17971329e-02,  4.47031113e-01,
#         9.96475952e-01,  2.52451582e+00,  8.26451012e-01,  1.81470991e+00,
#         2.13248025e-01,  8.20633373e-01,  1.27160555e-02,  3.50759657e-01,
#         1.10121596e+00,  4.38879219e-01,  3.58941812e-01,  1.46780612e+00,
#         1.83648526e-01,  1.16778608e-01,  2.71044369e-01,  4.16777623e-01,
#         9.14034780e-01,  2.57507085e-01,  2.02055464e-01,  1.75295857e-01,
#         4.47768080e-01,  4.33996899e-02,  5.33482081e-01,  7.75029090e-01,
#         3.23592110e-01,  5.77043821e-01,  2.03974110e-02,  1.09574594e+00,
#         9.21306375e-01,  1.07253698e+00,  6.05814295e-01, -6.46215513e-02,
#         6.01508397e-01,  2.38516972e-01,  7.24890179e-02,  6.10716722e-01,
#         2.21905453e+00,  7.35207240e-01,  1.57745469e+00,  2.03493178e+00,
#         1.24184189e+00,  6.19244350e-01,  1.57147787e-02,  8.55051336e-01,
#         8.70231971e-01,  5.15016229e-01,  9.59413546e-01,  1.20529842e-01,
#         1.77530709e-01,  7.94519320e-02,  9.65487423e-01,  3.00691620e-01,
#         9.68208238e-01,  2.11454340e-01,  4.04155863e-02,  8.48991649e-01,
#         5.04284145e-01,  1.56929650e+00,  1.74261710e+00,  5.01012855e-01,
#         9.32846170e-01,  1.12890616e+00,  1.82589236e-01,  1.32054748e-01,
#         3.48779776e-01,  2.33208875e-01,  2.01090011e+00,  1.48114731e+00,
#         7.85400090e-01,  5.70041285e-01,  6.68040349e-01,  3.94918378e-01,
#         5.67308186e-01,  4.11318899e-01,  1.42348484e+00,  1.99382063e+00,
#         2.69166677e-01,  6.54624071e-01,  1.10064944e+00,  2.77896026e-01,
#         1.31486828e-01,  3.87315178e-01,  4.84420990e-01,  1.00834344e+00,
#         3.75551815e-01,  5.62197288e-01,  1.13195794e-01, -2.99460482e-02,
#         7.17358751e-01,  5.03987782e-02,  3.09196760e+00,  1.87049229e+00,
#         2.03737909e+00,  1.22822340e-01,  1.46263832e-01,  1.59079808e+00,
#         1.23424357e-01,  2.36691581e+00,  1.11237354e+00,  1.15720252e+00,
#         3.32663796e+00,  6.06751022e-01,  2.84215250e-01,  5.16985697e-01,
#         2.28617944e+00,  1.67802619e+00,  7.46253372e-01,  1.76670882e+00,
#         4.71063410e-02,  6.79900203e-01,  1.19161354e+00,  7.72259832e-01,
#         1.25862056e+00,  1.12680041e-01,  7.05489924e-01,  1.82646759e+00,
#         5.79230908e-01,  9.75361290e-01, -5.69770667e-02,  1.30718449e+00,
#         1.07816728e+00,  6.64838225e-01,  4.11817265e-01,  3.59239279e-01,
#        -4.78672217e-02,  2.24804769e-01,  9.43363575e-01,  4.26727966e-01,
#         6.78347413e-01,  1.23028775e+00,  9.97653246e-01,  2.89569838e-01,
#         8.60548040e-01,  9.52853993e-01,  1.50042292e+00,  9.54915846e-01,
#         2.48396580e-01,  8.55432331e-01,  1.60469565e+00,  9.68791171e-01,
#         2.95084690e+00,  8.93361621e-02,  3.98708098e-01,  9.50866149e-01,
#         2.74485420e+00,  1.36678705e+00,  1.28795063e+00,  9.00865976e-01,
#         1.30324186e+00,  2.37094859e+00,  1.34030807e+00,  5.15161426e-01,
#         1.24915322e-01,  3.15365638e-01,  1.74899237e-01,  1.41952054e-01,
#         1.44265154e+00,  2.45588252e-01,  6.92316698e-02, -4.90110857e-02,
#         1.22923390e+00,  1.00174050e-01,  5.38819609e-01,  1.42201210e+00,
#         9.53109196e-01, -4.14283336e-02,  9.26249027e-01,  1.99085193e-01,
#         7.19271618e-01,  2.48374371e+00,  7.94937106e-01,  2.54009746e+00,
#         8.86188118e-01,  2.42905067e-01,  2.88633400e-01,  1.54016943e-01,
#         1.64712222e+00,  8.46976870e-01,  1.45086415e+00,  6.56317680e-01,
#        -3.94854688e-02,  1.75426275e-02,  2.63161467e-01,  9.02257102e-01,
#         4.66628835e-01,  4.43076630e-01,  8.36559444e-01,  2.23719418e-01,
#         8.79808812e-01,  7.52787359e-01,  9.72954465e-01,  4.54134473e-01,
#         1.95091517e+00,  1.36478844e+00,  1.44188101e+00,  1.00292411e+00,
#         2.92995157e-01,  9.85397400e-01,  8.58622301e-01,  5.39272191e-01,
#        -6.96479813e-03,  7.17995124e-02,  2.12829309e-01,  9.15602207e-01,
#         1.81616959e+00,  8.53835934e-01,  1.35038311e+00,  6.73482754e-01,
#         2.48729349e+00,  6.23783817e-01,  5.12696952e-02,  2.00607030e-01,
#         1.26658674e+00,  2.93214773e-01,  2.53261152e-01,  1.77236991e+00,
#         1.00840173e+00,  4.30435839e-01,  8.80024443e-01,  1.84341530e+00,
#         1.43466271e+00,  2.03766121e-01,  1.18723065e+00,  4.41654994e-02,
#         1.66042615e+00,  3.66684915e-01,  9.46423847e-02,  1.44590248e+00,
#         5.45575148e-01,  5.80742605e-01,  1.22024908e+00,  8.23269109e-01,
#         1.53972096e+00,  7.27004062e-01,  9.46853765e-01,  4.30750696e-01,
#         4.89308047e-01,  3.07058333e-01,  2.97199309e-01,  1.55476993e+00,
#         7.18363378e-01,  2.00469642e-01,  7.80407656e-01,  4.11916066e-01,
#         1.70631091e-01,  6.63497298e-01,  1.19473013e+00,  1.62244636e+00,
#         4.21221926e-01,  7.17576937e-02,  1.33385146e-01,  2.28545417e-01,
#         5.53694398e-01,  1.14176196e-01,  2.08531279e-01,  1.04286149e+00,
#         4.99068836e-01,  3.59606197e-02,  1.66648940e+00,  3.48081951e-01,
#         1.01247400e+00,  1.78113162e+00,  2.46846357e+00,  1.12124991e+00,
#         7.53051230e-01,  5.74650678e-01,  1.66609369e+00,  5.97350855e-01,
#         9.90440147e-02,  1.08030606e+00,  3.51704611e-01,  9.48961992e-01,
#         1.54443607e+00,  1.04703620e-01,  8.55492590e-01,  2.25681889e-01,
#         6.82159146e-01,  2.12920805e-01,  2.53865424e-01,  2.00040481e-01,
#         2.09617811e-01,  5.91662672e-01,  1.55764927e+00,  1.94274106e+00,
#         1.13838871e+00,  1.04426909e+00,  3.68257730e-01,  1.04598169e+00,
#         1.43815008e+00,  1.48887223e+00,  1.12024544e+00,  1.53024741e+00,
#         9.74384995e-02,  8.63003652e-01,  1.84483175e+00,  4.62000767e-01,
#         2.37360961e+00,  1.25082403e+00,  1.32596662e+00,  9.93120592e-02,
#         1.68042939e+00,  8.88836955e-03,  8.80462760e-01,  2.22578813e-01,
#         2.22788184e-01,  5.97966802e-01,  2.05413359e+00,  1.67261099e+00,
#         1.10753916e+00,  5.13759386e-01,  8.62666852e-01,  5.79349315e-01,
#         8.44447759e-01,  7.74077639e-01,  5.46038418e-01,  4.75706809e-01,
#         8.01584730e-01,  1.44562775e+00,  8.73220758e-01,  4.92655223e-01,
#         2.00302973e-01,  1.83386411e+00,  3.66811664e-02,  4.88416204e-01,
#         9.26192403e-01,  1.30245251e+00,  5.41780346e-02,  1.11995404e+00,
#         1.01552511e+00,  1.25515235e+00,  1.62611207e+00,  4.54861992e-01,
#         1.12290352e+00,  3.31104618e-01,  1.58733031e+00,  1.79166287e+00,
#         8.86793561e-02,  1.02600291e+00,  1.93471326e+00,  4.90782414e-01,
#         1.08151238e+00,  6.84742648e-01,  2.82803491e+00,  3.72519232e-02,
#         2.99903042e-01,  2.78758661e-01,  2.24071768e+00,  5.69366406e-01,
#         4.90159021e-01,  1.81158631e+00,  5.32642901e-01,  4.27326612e-01,
#        -1.72259756e-04,  4.44531056e-01,  1.39347828e-01,  1.47503183e+00,
#         4.71673984e-01,  8.14661151e-01,  1.18925507e+00,  4.33893080e-01,
#         1.74522267e+00,  2.64526403e-01,  5.56340732e-01,  5.68322669e-01,
#        -5.36822830e-02, -1.03260980e-01,  2.74174436e-01,  5.84421296e-01,
#         3.50267035e-01,  9.17433445e-01,  4.25939680e-01,  8.69902709e-02,
#         1.28892368e-01,  7.80954457e-02,  2.78503356e-01,  4.32905034e-02,
#        -1.38783981e-01,  4.61828561e-01,  1.28245619e+00,  4.09319922e-01,
#         2.50569831e+00,  9.54951565e-02,  6.81972049e-01,  4.33751868e-01,
#         8.26097368e-01,  1.91351130e+00,  8.99073047e-01,  8.17844293e-01,
#         1.61791417e+00,  1.33308136e+00,  8.63950064e-01,  1.02858265e+00,
#         8.01376953e-01,  5.38496600e-01,  7.15836954e-01,  3.91520367e-01,
#         1.56479389e+00,  3.65545732e-01,  6.10877077e-01,  7.94047504e-01,
#         1.21695243e+00,  2.32873228e+00,  1.19981159e-01,  1.04373936e+00,
#         5.71260907e-01,  1.05582613e-01,  6.35161756e-01,  5.62754525e-01,
#         1.11685520e-01,  9.20846661e-01,  7.24325318e-01,  1.90373750e-01,
#         5.75451754e-01,  1.46179192e+00,  1.23744426e+00,  1.13746263e+00,
#         6.83519742e-01,  1.07950372e-01,  8.11545843e-01,  8.98900950e-01,
#         4.82618277e-01,  7.41801772e-01,  8.28556661e-01,  9.80747074e-01,
#         1.96504540e-01,  9.30958049e-02,  1.94137409e-01,  3.32381336e-01,
#         4.59201925e-01,  9.45563057e-01,  1.17870258e+00,  9.20066228e-01,
#         8.01531444e-02,  1.51771766e+00, -2.07739928e-03,  9.37484164e-01,
#         1.02339433e+00, -7.53189316e-03,  6.98759831e-01,  4.85455621e-01,
#         2.21876186e-01,  1.50075777e-01,  1.08317993e+00,  1.14896633e-01,
#         3.09988124e+00,  4.86576293e-02,  1.73915146e-01,  1.52707248e+00,
#         1.72075431e-01, -1.79345921e-02,  1.59281722e+00,  2.72130591e-01,
#         5.41467939e-01,  5.26289437e-01,  9.81206812e-01,  6.81947651e-01,
#         1.05473685e+00,  6.89712391e-01,  6.44060598e-01,  6.13508778e-01,
#         5.80372674e-02,  4.12702674e-01,  1.85426007e-01,  5.45487229e-01,
#         1.28367265e+00,  4.91201559e-01,  4.44162481e-01,  1.86563087e-01,
#         8.77054102e-01,  3.83904619e-01,  4.24597833e-01,  1.07002727e-01,
#         9.15783783e-02,  1.34747541e+00,  1.15212654e-01,  1.39981052e+00,
#         1.79051790e+00,  5.27638276e-01,  7.02335609e-01,  1.21400510e+00,
#         2.06743619e-01,  5.41777435e-01,  4.80363687e-01,  2.39195530e+00,
#         8.46819494e-02,  4.95569149e-01,  1.32954770e+00,  4.81457333e-01,
#         6.17402541e-01,  9.84075642e-01,  7.87438262e-02,  3.98207386e-01,
#         4.14320660e-01,  7.90802741e-01,  6.12727093e-01,  1.99834154e+00,
#         5.88374520e-01,  6.22276324e-01,  6.63656016e-01,  5.40194907e-02,
#         1.84993402e+00,  4.33210774e-01,  1.55843590e-01,  6.89027896e-01,
#         3.16779249e-01,  2.72651189e-01,  1.06692911e-01,  4.10515182e-01,
#         3.84427658e-02,  2.29270282e+00,  1.88587354e+00,  2.30857111e+00,
#         7.26465778e-02,  4.98012223e-01,  4.71869143e-01,  1.22206759e+00,
#         7.01780316e-01,  9.93984800e-01,  1.50862959e-01,  1.55557899e+00,
#         2.26407415e-01,  4.06125890e-01,  8.82686591e-01,  1.98154540e-01,
#         2.66584430e+00,  1.50170910e+00,  7.32309753e-01, -3.85104665e-02,
#         1.23144728e+00,  1.67097508e-01,  8.24900159e-01,  2.47539886e-01,
#         1.96161500e-02,  1.69328100e+00,  2.60770854e-01,  1.40126977e+00,
#         6.00759034e-01,  1.61923912e+00,  2.11798279e-01,  1.25136915e-01,
#         2.40068797e+00,  5.81904395e-02,  1.63422548e+00,  1.48087760e+00,
#         2.48928681e+00,  5.92370342e-01,  3.28037202e+00,  1.33306422e-01,
#         1.47751548e-01,  7.41659990e-01,  4.90742622e-02,  4.28419841e-01,
#         5.46457144e-01,  2.45227933e-01,  9.35690934e-02,  1.49939333e+00,
#         1.92508239e-01,  2.79651860e-01,  5.87346947e-01,  1.46113237e+00,
#         1.53256535e+00,  3.01115890e-01,  5.97920845e-01, -8.20537957e-02,
#         4.30890984e-01,  1.23457918e+00,  4.57162902e-01,  3.47216717e-01,
#         7.62064115e-01,  3.75664484e-01,  1.19306538e-01,  2.45696762e+00,
#         1.23193326e+00,  1.81724933e-01,  4.03968190e-01,  4.88264864e-01,
#         2.23589681e-01,  1.55133983e+00,  1.13027934e+00,  3.29324007e-01,
#         2.34448041e-02,  9.01760851e-01,  3.78249402e-01,  1.31190152e+00,
#         3.71979294e-01,  1.25002800e+00,  1.25440471e+00,  1.84490911e-01,
#         1.82061371e+00,  1.78224217e+00,  5.36487155e-01,  1.37247545e+00,
#         1.96976554e+00,  8.25896845e-02,  4.15590651e-01,  9.11449519e-01,
#         1.23079020e-02,  1.38052197e-01, -5.91639368e-02,  8.99813481e-01,
#         4.30121053e-01,  1.87880575e+00,  9.71009140e-01,  2.01276882e+00,
#         1.68755160e+00,  6.05979554e-01,  1.21779662e+00,  1.69947336e-01,
#         1.30681447e+00,  2.48462208e+00,  8.75336665e-01,  1.76213108e+00,
#         2.26458459e-01,  9.01618312e-01,  4.59328078e-01,  9.21060587e-01,
#         1.16958313e+00,  1.12480302e+00,  1.50444268e+00,  9.48871543e-01,
#         7.24717355e-02,  2.18130271e-01,  1.26210787e+00,  3.62461885e-01,
#         1.05122819e+00,  9.73333098e-01,  1.13389324e+00,  3.13946695e-01,
#         1.45925143e-01,  4.03141131e-01,  5.69707702e-01,  1.06031820e-01,
#         2.31047966e-01,  7.20985443e-01,  1.27170786e+00,  1.35097292e+00,
#         1.70785224e+00,  1.70001287e+00,  1.58179774e+00,  3.08156748e-01,
#         3.80397354e-01,  2.13395315e+00,  1.19898916e-01,  5.29663684e-01,
#         1.20106493e+00,  4.67572289e-01,  7.43397554e-01,  2.26825707e-01,
#         1.99177897e-01,  3.45915512e-01,  8.30692624e-01,  2.16046816e+00,
#         4.55116476e-01,  1.20266010e+00,  2.42713254e-01,  1.16559867e+00,
#        -1.18912241e-02,  4.78499171e-01,  1.11875127e+00,  6.13371519e-01,
#         2.14583118e-01,  2.32667634e+00,  5.57592809e-01,  8.17895540e-01,
#         9.07751445e-01,  5.03910720e-01,  6.09588737e-01, -1.27064200e-01,
#         7.93645566e-01,  7.23026752e-01,  9.38587401e-01,  2.64402312e-01,
#         1.33447600e+00,  3.85529839e-01,  8.50091196e-01,  6.78518618e-01,
#         1.07981237e+00,  4.31307946e-01,  2.90284569e-01,  1.33422480e+00,
#         4.12061581e-01,  1.08441477e+00,  1.97313997e+00,  1.09951776e+00,
#         5.28623533e-01,  5.29486545e-02,  2.00549011e+00,  4.91825995e-02,
#         1.47888906e+00,  6.36178222e-01,  1.65588930e+00,  1.09940939e+00,
#         7.90981313e-01,  1.59388803e+00,  7.68598200e-01,  3.92900727e-01,
#         8.86082177e-01,  1.11270630e+00,  6.76906328e-01,  1.10901236e-01,
#         1.58930315e+00,  4.33884168e-01,  1.80999507e+00,  1.81186962e+00,
#         2.97332497e-01,  6.04257120e-01,  1.01283124e-01, -1.35415831e-02,
#         2.41562212e-01,  8.15052361e-01,  3.04760355e-01,  4.17058404e-01,
#         1.25049305e+00,  1.12932928e+00,  2.94614355e-01,  3.48260284e-01,
#         1.44628809e+00,  3.88960540e-01,  4.61487327e-01,  4.25457464e-01,
#         8.22224857e-01,  8.13561158e-01,  1.58008992e+00,  4.60795243e-01,
#         4.45315332e-01,  2.94148541e-01,  1.21213065e+00,  2.65404666e-01,
#         7.36945238e-01,  7.47157877e-01,  1.98419972e-01,  7.70966733e-01,
#         2.09906752e-01,  1.10523824e+00,  1.09292119e+00,  2.55121290e-01,
#         1.96372954e-01,  9.41967620e-01,  9.77954686e-01,  1.39340517e+00,
#         3.52232936e-01,  1.19258382e+00,  3.12435440e-01,  1.19124082e+00,
#         2.22513583e+00,  5.46388686e-01,  2.69760629e-01,  6.39560595e-01,
#         2.34262282e+00,  2.02818286e+00,  4.67657075e-01,  3.47881150e-01,
#         1.38368071e-01,  9.01780289e-01,  5.63328104e-01,  1.14507846e+00,
#         3.58445679e-01,  2.52828349e-01,  6.47998676e-01,  1.24246378e+00,
#         2.17002710e-01,  2.03786064e+00,  2.06309177e-01,  8.18153961e-01])

# %%
# plot

plt.rcParams['figure.figsize'] = (10.0, 5.0)

plt.plot(np.cumsum(stock_a))
plt.show()

# %%
plt.rcParams['figure.figsize'] = (10.0, 5.0)

sns.histplot(stock_a)
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
# Mean > Median --> Skew to the right

plt.rcParams['figure.figsize'] = (10.0, 5.0)

sns.histplot(stock_a)

plt.axvline(np.mean(stock_a), color = 'Blue', linewidth = 2, linestyle = '--')
plt.axvline(np.median(stock_a), color = 'Green', linewidth = 2, linestyle = '--')

print(f'Mean: {np.round(np.mean(stock_a), 5)}%')
print(f'Median: {np.round(np.median(stock_a), 5)}%')
# Out:
# Mean: 0.79735%
# Median: 0.64627%

# %%
# Mean < Median --> Skew to the left

stock_b = skewnorm.rvs(-10, size = 1000)
plt.plot(np.cumsum(stock_b));

# %%
plt.rcParams['figure.figsize'] = (10.0, 5.0)

sns.histplot(stock_b)

plt.axvline(np.mean(stock_b), color = 'Blue', linewidth = 2, linestyle = '--')
plt.axvline(np.median(stock_b), color = 'Green', linewidth = 2, linestyle = '--')

print(f'Mean: {np.round(np.mean(stock_b), 5)}%')
print(f'Median: {np.round(np.median(stock_b), 5)}%')
# Out:
# Mean: -0.81094%
# Median: -0.67847%

# %%
stock_c = skewnorm.rvs(-5, size = 1000)

sns.histplot(stock_c)

plt.axvline(np.mean(stock_c), color = 'Blue', linewidth = 2, linestyle = '-.') # dash-dot line style
plt.axvline(np.median(stock_c), color = 'Green', linewidth = 2, linestyle = '-.')

print(f'Mean: {np.round(np.mean(stock_c), 5)}%')
print(f'Median: {np.round(np.median(stock_c), 5)}%')
# Out:
# Mean: -0.78304%
# Median: -0.66622%

# %%
stock_d = skewnorm.rvs(-2, size = 1000)

sns.histplot(stock_d)

plt.axvline(np.mean(stock_d), color = 'Blue', linewidth = 2, linestyle = ':') # dotted line style
plt.axvline(np.median(stock_d), color = 'Green', linewidth = 2, linestyle = ':')

print(f'Mean: {np.round(np.mean(stock_d), 5)}%')
print(f'Median: {np.round(np.median(stock_d), 5)}%')
# Out:
# Mean: -0.71875%
# Median: -0.6807%

# %%
bdms_pct.plot();

# %%
# plot bdms_pct

sns.histplot(bdms_pct)

plt.axvline(np.mean(bdms_pct), color = 'Blue', linewidth = 2, linestyle = '-.') # dash-dot line style
plt.axvline(np.median(bdms_pct), color = 'Green', linewidth = 2, linestyle = '-.')

print(f'Mean: {np.round(np.mean(bdms_pct), 5)}%')
print(f'Median: {np.round(np.median(bdms_pct), 5)}%')
# Out:
# Mean: 0.00046%
# Median: 0.0%

# %% [markdown]
# ### Quantile and Percentile

# %%
bdms_pct.quantile(0.25) * 100
# Out:
# -0.8771929824561431

# %%
sns.histplot(bdms_pct, color = 'blue')
plt.title("BDMS Return")

q1 = bdms_pct.quantile(0.25)
q2 = bdms_pct.quantile(0.5)
q3 = bdms_pct.quantile(0.75)

plt.axvline(x = q1, linewidth = 2, color = 'Red', linestyle = ':')
plt.figtext(0.3, 0.55, f"Q1:{q1 * 100:.4}  %", fontsize = 10)

plt.axvline(x = q2, linewidth = 2, color = 'Blue', linestyle = ':')
plt.figtext(0.4, 0.65, f"Q2:{q2 * 100:.4}  %", fontsize = 10)

plt.axvline(x = q3, linewidth = 2, color = 'Green', linestyle = ':')
plt.figtext(0.6, 0.75, f"Q1:{q3 * 100:.4}  %", fontsize = 10)
plt.show()

# %% [markdown]
# ### Percentile

# %%
np.percentile(bdms_pct, 1) * 100 # at percentile #1
# Out:
# -3.9005054063410234

# %%
sns.histplot(bdms_pct, color = 'blue')
plt.title("BDMS Return")

p1 = np.percentile(bdms_pct, 1) # P1
p99 = np.percentile(bdms_pct, 99) # P99

plt.axvline(x = p1, linewidth = 2, color = 'Red', linestyle = '--')
plt.figtext(0.25, 0.65, f"P1:{q1 * 100:.4}  %", fontsize = 10)

plt.axvline(x = p99, linewidth = 2, color = 'Green', linestyle = '--')
plt.figtext(0.70, 0.55, f"P99:{q3 * 100:.4}  %", fontsize = 10)
plt.show()

# %% [markdown]
# ### Variance and Standard Deviation

# %%
# 2 sets of 5 numbers that have the same mean but different standard deviations

set1 = (21, 19, 22, 18, 20) # 21%, 19%, 22%, 18%, and 20% in 5 years rang
set2 = (55, -15, -25, 55, 30)

print(f'Mean of SET1: {np.mean(set1)}')
print(f'Mean of SET2: {np.mean(set2)}')
# Out:
# Mean of SET1: 20.0
# Mean of SET2: 20.0

# %%
plt.rcParams['figure.figsize'] = (10.0, 5.0)

plt.plot(set1, label = "SET 1", marker='o')
plt.plot(set2, label = "SET 2", marker='o')
plt.legend()
plt.show()

# %%
plt.rcParams['figure.figsize'] = (10.0, 5.0)

plt.plot(np.cumsum(set1), label = "SET 1", marker='o')
plt.plot(np.cumsum(set2), label = "SET 2", marker='o')
plt.legend()
plt.show()

# %% [markdown]
# #### What are the symbols we need to write?
# - Hat: \hat
# - Bar: \bar
# - Square root: \sqrt{}
# - Subscript: _{}
# - Sum: \sum
# - Limits of sum: \limits _{} ^{}
# - Beta: \beta
#
# - Note $$ : All the Math you want to write in the markdown should be inside opening and closing $ symbol in order to be processed as Math.
# - \beta : Creates the symbol beta
# - \hat{} : A hat is covered over anything inside the curly braces of \hat{}. E.g. in \hat{Y} hat is created over Y and in \hat{\beta}_{0},  hat is shown over beta
# - _{} : Creates as subscript, anything inside the curly braces after _. E.g. \hat{\beta}_{0} will create beta with a hat and give it a subscript of 0.
# - ^{} : (Similar to subscript) Creates as superscript, anything inside the curly braces after ^.
# - \sum : Creates the summation symbol
# - \limits _{} ^{} : Creates lower and upper limit for the \sum using the subscript and superscript notation.

# %% [markdown]
# ### Variance
#
# $$
# {S}^2 = \frac{{\sum(X - \bar{X})}^2}{N - 1}
# $$

# %%
set1, np.mean(set1), len(set1)
# Out:
# ((21, 19, 22, 18, 20), 20.0, 5)

# %%
set2
# Out:
# (55, -15, -25, 55, 30)

# %%
# apply for loop

sum_set1 = 0

for n in range(0, len(set1)):

    diff = (set1[n] - np.mean(set1)) ** 2
    print(diff)

    sum_set1 += diff

print(f'SUM diff: {sum_set1}')
print(f'VAR: {sum_set1/len(set1)}')
# Out:
# 1.0
# 1.0
# 4.0
# 4.0
# 0.0
# SUM diff: 10.0
# VAR: 2.0

# %%
# apply for loop

sum_set2 = 0

for n in range(0, len(set2)):

    diff = (set2[n] - np.mean(set2)) ** 2
    print(diff)

    sum_set2 += diff

print(f'SUM diff: {sum_set2}')
print(f'VAR: {sum_set2/len(set2)}')
# Out:
# 1225.0
# 1225.0
# 2025.0
# 1225.0
# 100.0
# SUM diff: 5800.0
# VAR: 1160.0

# %%
# apply Vectorization

np.sum(((set1 - np.mean(set1)) ** 2)) / len(set1)
# Out:
# 2.0

# %%
# apply Vectorization

np.sum(((set2 - np.mean(set2)) ** 2)) / len(set2)
# Out:
# 1160.0

# %%
# apply build-in function

var_set1 = np.var(set1)
var_set1
# Out:
# 2.0

# %%
# apply build-in function

var_set2 = np.var(set2)
var_set2
# Out:
# 1160.0

# %% [markdown]
# ### Standard Deviation (Volatility)
#
# $$
# S = \sqrt{\frac{{\sum(X - \bar{X})}^2}{N - 1}}
# $$

# %%
var_set1 ** (1/2)
# Out:
# 1.4142135623730951

# %%
var_set2 ** 0.5
# Out:
# 34.058772731852805

# %%
print(f'Standard Deviation of system A:{var_set1 ** 0.5:.4f}')
print(f'Standard Deviation of system B:{var_set2 ** 0.5:.4f}')
# Out:
# Standard Deviation of system A:1.4142
# Standard Deviation of system B:34.0588

# %%
# apply to real data

gulf = pd.read_csv('Data/SET50_download_r2/GULF.BK.csv', index_col = 0)
gulf.set_index(pd.to_datetime(gulf.index), inplace = True)
gulf.head()
# Out:
#                  Open       High        Low      Close  Adj Close      Volume
# Date
# 2017-12-06  11.370276  11.765764  10.332120  10.628736  10.045855  1230996513
# 2017-12-07  10.678172  10.678172  10.035504  10.084940   9.531880   268224149
# 2017-12-08  10.332120  10.925352  10.332120  10.826480  10.232754   297947437
# 2017-12-12  10.875916  10.875916  10.430992  10.430992   9.858955   160721992
# 2017-12-13  10.480428  10.727608  10.332120  10.678172  10.092581   113506386

# %%
gulf.index
# Out:
# DatetimeIndex(['2017-12-06', '2017-12-07', '2017-12-08', '2017-12-12',
#                '2017-12-13', '2017-12-14', '2017-12-15', '2017-12-18',
#                '2017-12-19', '2017-12-20',
#                ...
#                '2024-02-12', '2024-02-13', '2024-02-14', '2024-02-15',
#                '2024-02-16', '2024-02-19', '2024-02-20', '2024-02-21',
#                '2024-02-22', '2024-02-23'],
#               dtype='datetime64[ns]', name='Date', length=1512, freq=None)

# %%
# setting

start = '2018'
end = '2023'

# %%
gulf = gulf[start : end]
gulf.tail()
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2023-12-22  45.50  45.50  44.50  44.75      44.75  13952200
# 2023-12-25  44.75  45.25  44.50  44.50      44.50   6274000
# 2023-12-26  44.50  44.75  43.75  44.25      44.25  15313000
# 2023-12-27  44.50  45.00  44.00  44.25      44.25  14321200
# 2023-12-28  44.50  44.75  44.25  44.50      44.50  14613400

# %%
# add a new calculated column for log return

gulf['log_return'] = np.log(gulf['Close']/gulf['Close'].shift(1))
gulf.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2018-01-03  12.902792  13.693767  12.902792  13.594895  12.849349  393597397
# 2018-01-04  13.545459  13.743203  13.248843  13.693767  12.942799  283553064
# 2018-01-05  13.792639  13.842075  13.594895  13.594895  12.849349  147190351
# 2018-01-08  13.397151  13.644331  13.347715  13.496023  12.755899   49365356
# 2018-01-09  13.446587  13.446587  13.446587  13.446587  12.709174    1481714
#
#             log_return
# Date
# 2018-01-03         NaN
# 2018-01-04    0.007246
# 2018-01-05   -0.007246
# 2018-01-08   -0.007299
# 2018-01-09   -0.003670

# %%
gulf['Close'].plot();

# %%
# variance

var = np.var(gulf['log_return'])

print(f'Variance of GULF from {start} to {end}: {var:.6f}')
# Out:
# Variance of GULF from 2018 to 2023: 0.000387

# %%
# Standard Deviation

std = np.std(gulf['log_return'])

print(f'Standard Deviation of GULF from {start} to {end}: {std:.6f}')
# Out:
# Standard Deviation of GULF from 2018 to 2023: 0.019679

# %%
gulf['log_return'].rolling(21).std()
# Out:
# Date
# 2018-01-03         NaN
# 2018-01-04         NaN
# 2018-01-05         NaN
# 2018-01-08         NaN
# 2018-01-09         NaN
#                 ...
# 2023-12-22    0.012534
# 2023-12-25    0.011748
# 2023-12-26    0.011781
# 2023-12-27    0.011274
# 2023-12-28    0.011277
# Name: log_return, Length: 1457, dtype: float64

# %%
gulf['log_return'].rolling(21).std().head(25)
# Out:
# Date
# 2018-01-03         NaN
# 2018-01-04         NaN
# 2018-01-05         NaN
# 2018-01-08         NaN
# 2018-01-09         NaN
# 2018-01-10         NaN
# 2018-01-11         NaN
# 2018-01-12         NaN
# 2018-01-15         NaN
# 2018-01-16         NaN
# 2018-01-17         NaN
# 2018-01-18         NaN
# 2018-01-19         NaN
# 2018-01-22         NaN
# 2018-01-23         NaN
# 2018-01-24         NaN
# 2018-01-25         NaN
# 2018-01-26         NaN
# 2018-01-29         NaN
# 2018-01-30         NaN
# 2018-01-31         NaN
# 2018-02-01    0.027428
# 2018-02-02    0.027897
# 2018-02-05    0.027846
# 2018-02-06    0.027793
# Name: log_return, dtype: float64

# %% [markdown]
# ### Detecting Outlier

# %%
# preprocessing data

gulf_outliners = gulf['log_return'].rolling(42).agg(['mean', 'std'])
gulf_outliners.head()
# Out:
#             mean  std
# Date
# 2018-01-03   NaN  NaN
# 2018-01-04   NaN  NaN
# 2018-01-05   NaN  NaN
# 2018-01-08   NaN  NaN
# 2018-01-09   NaN  NaN

# %%
gulf_outliners.tail()
# Out:
#                 mean       std
# Date
# 2023-12-22  0.001510  0.012231
# 2023-12-25  0.000816  0.011770
# 2023-12-26  0.000821  0.011767
# 2023-12-27  0.000821  0.011767
# 2023-12-28  0.000816  0.011765

# %%
gulf_outliners = gulf.join(gulf_outliners)
gulf_outliners.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2018-01-03  12.902792  13.693767  12.902792  13.594895  12.849349  393597397
# 2018-01-04  13.545459  13.743203  13.248843  13.693767  12.942799  283553064
# 2018-01-05  13.792639  13.842075  13.594895  13.594895  12.849349  147190351
# 2018-01-08  13.397151  13.644331  13.347715  13.496023  12.755899   49365356
# 2018-01-09  13.446587  13.446587  13.446587  13.446587  12.709174    1481714
#
#             log_return  mean  std
# Date
# 2018-01-03         NaN   NaN  NaN
# 2018-01-04    0.007246   NaN  NaN
# 2018-01-05   -0.007246   NaN  NaN
# 2018-01-08   -0.007299   NaN  NaN
# 2018-01-09   -0.003670   NaN  NaN

# %%
gulf_outliners.tail()
# Out:
#              Open   High    Low  Close  Adj Close    Volume  log_return  \
# Date
# 2023-12-22  45.50  45.50  44.50  44.75      44.75  13952200   -0.016621
# 2023-12-25  44.75  45.25  44.50  44.50      44.50   6274000   -0.005602
# 2023-12-26  44.50  44.75  43.75  44.25      44.25  15313000   -0.005634
# 2023-12-27  44.50  45.00  44.00  44.25      44.25  14321200    0.000000
# 2023-12-28  44.50  44.75  44.25  44.50      44.50  14613400    0.005634
#
#                 mean       std
# Date
# 2023-12-22  0.001510  0.012231
# 2023-12-25  0.000816  0.011770
# 2023-12-26  0.000821  0.011767
# 2023-12-27  0.000821  0.011767
# 2023-12-28  0.000816  0.011765

# %%
# detecting outlier function

def outlier_detection(df, n_sigmas = 3):

    x = df['log_return'] # return
    mu = df['mean']
    sigma = df['std']

    if (x > mu + sigma * n_sigmas) | (x < mu - sigma * n_sigmas):
        return 1
    else:
        return 0

# %%
gulf_outliners['outlier'] = gulf_outliners.apply(outlier_detection, axis = 1)
gulf_outliners.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2018-01-03  12.902792  13.693767  12.902792  13.594895  12.849349  393597397
# 2018-01-04  13.545459  13.743203  13.248843  13.693767  12.942799  283553064
# 2018-01-05  13.792639  13.842075  13.594895  13.594895  12.849349  147190351
# 2018-01-08  13.397151  13.644331  13.347715  13.496023  12.755899   49365356
# 2018-01-09  13.446587  13.446587  13.446587  13.446587  12.709174    1481714
#
#             log_return  mean  std  outlier
# Date
# 2018-01-03         NaN   NaN  NaN        0
# 2018-01-04    0.007246   NaN  NaN        0
# 2018-01-05   -0.007246   NaN  NaN        0
# 2018-01-08   -0.007299   NaN  NaN        0
# 2018-01-09   -0.003670   NaN  NaN        0

# %%
gulf_outliners.tail()
# Out:
#              Open   High    Low  Close  Adj Close    Volume  log_return  \
# Date
# 2023-12-22  45.50  45.50  44.50  44.75      44.75  13952200   -0.016621
# 2023-12-25  44.75  45.25  44.50  44.50      44.50   6274000   -0.005602
# 2023-12-26  44.50  44.75  43.75  44.25      44.25  15313000   -0.005634
# 2023-12-27  44.50  45.00  44.00  44.25      44.25  14321200    0.000000
# 2023-12-28  44.50  44.75  44.25  44.50      44.50  14613400    0.005634
#
#                 mean       std  outlier
# Date
# 2023-12-22  0.001510  0.012231        0
# 2023-12-25  0.000816  0.011770        0
# 2023-12-26  0.000821  0.011767        0
# 2023-12-27  0.000821  0.011767        0
# 2023-12-28  0.000816  0.011765        0

# %%
# filter data

condition = gulf_outliners['outlier'] == 1
condition
# Out:
# Date
# 2018-01-03    False
# 2018-01-04    False
# 2018-01-05    False
# 2018-01-08    False
# 2018-01-09    False
#               ...
# 2023-12-22    False
# 2023-12-25    False
# 2023-12-26    False
# 2023-12-27    False
# 2023-12-28    False
# Name: outlier, Length: 1457, dtype: bool

# %%
gulf_outliners[condition]
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2019-05-16  20.268753  20.466497  18.884546  19.329470  18.591843  149157036
# 2019-08-21  24.816864  26.497686  24.717993  26.299944  25.296320   93483522
# 2019-09-02  28.475126  31.737902  28.475126  31.342415  30.146366  118194772
# 2020-01-13  35.198421  38.263451  35.099548  38.263451  36.803291  122929178
# 2020-03-11  33.023235  33.319855  29.463846  29.958206  29.034424  108313306
# 2020-03-12  26.695431  27.486406  23.234913  25.904455  25.105673  176602631
# 2020-07-23  35.099548  35.593910  32.874928  33.863647  32.819435  263421372
# 2020-11-05  29.500000  31.500000  29.500000  31.250000  30.286385   61092300
# 2021-04-20  33.000000  34.750000  32.750000  34.250000  33.563564   90326000
# 2021-08-04  33.750000  36.000000  33.250000  36.000000  35.278492   61424800
# 2021-08-06  35.500000  37.500000  35.000000  37.250000  36.503441   92519300
# 2021-12-16  41.250000  42.750000  41.000000  42.750000  41.893211   57801300
# 2022-01-12  47.250000  49.500000  47.000000  49.500000  48.507923   65169300
# 2022-03-07  49.000000  49.250000  46.000000  46.500000  45.968571   83517300
# 2022-08-26  50.000000  51.500000  49.750000  51.500000  50.911427   31558900
# 2022-09-06  52.250000  56.500000  52.250000  56.000000  55.360001  112378300
# 2023-03-14  50.500000  50.750000  48.500000  48.750000  48.750000   35550600
# 2023-05-15  51.750000  51.750000  47.750000  48.000000  48.000000   68780000
#
#             log_return      mean       std  outlier
# Date
# 2019-05-16   -0.047450  0.002099  0.015564        1
# 2019-08-21    0.062035  0.003775  0.018716        1
# 2019-09-02    0.089021  0.005182  0.022933        1
# 2020-01-13    0.089128  0.002943  0.023230        1
# 2020-03-11   -0.106350 -0.003704  0.033451        1
# 2020-03-12   -0.145388 -0.009288  0.036966        1
# 2020-07-23   -0.077231 -0.003244  0.022793        1
# 2020-11-05    0.074724 -0.000565  0.020659        1
# 2021-04-20    0.060169 -0.000516  0.015386        1
# 2021-08-04    0.064539  0.000671  0.015239        1
# 2021-08-06    0.055186  0.002174  0.017398        1
# 2021-12-16    0.041797 -0.000551  0.013995        1
# 2022-01-12    0.062520  0.003912  0.016867        1
# 2022-03-07   -0.067558 -0.000381  0.020376        1
# 2022-08-26    0.034571  0.002304  0.010674        1
# 2022-09-06    0.093526  0.004299  0.017994        1
# 2023-03-14   -0.040206 -0.002435  0.011673        1
# 2023-05-15   -0.089612 -0.001209  0.019751        1

# %%
gulf_outliners[condition].shape
# Out:
# (18, 10)

# %%
outliers = gulf_outliners.loc[gulf_outliners['outlier'] == 1, ['log_return']] # get only column 'log_return and it's index
outliers
# Out:
#             log_return
# Date
# 2019-05-16   -0.047450
# 2019-08-21    0.062035
# 2019-09-02    0.089021
# 2020-01-13    0.089128
# 2020-03-11   -0.106350
# 2020-03-12   -0.145388
# 2020-07-23   -0.077231
# 2020-11-05    0.074724
# 2021-04-20    0.060169
# 2021-08-04    0.064539
# 2021-08-06    0.055186
# 2021-12-16    0.041797
# 2022-01-12    0.062520
# 2022-03-07   -0.067558
# 2022-08-26    0.034571
# 2022-09-06    0.093526
# 2023-03-14   -0.040206
# 2023-05-15   -0.089612

# %%
# plot

plt.rcParams['figure.figsize'] = (10.0, 5.0)

fig, ax = plt.subplots()

ax.plot(gulf_outliners.index, gulf_outliners['log_return'], label = 'Normal')

ax.legend()
plt.show()

# %%
# plot

plt.rcParams['figure.figsize'] = (10.0, 5.0)

fig, ax = plt.subplots()

ax.scatter(outliers.index, outliers['log_return'], color = 'Red', label = 'Outlier')

ax.set_title(f'GULF outlier')
ax.legend()
plt.show()

# %%
# plot

plt.rcParams['figure.figsize'] = (10.0, 5.0)

fig, ax = plt.subplots()

ax.plot(gulf_outliners.index, gulf_outliners['log_return'], label = 'Normal')
ax.scatter(outliers.index, outliers['log_return'], color = 'Red', label = 'Outlier')

ax.set_title(f'GULF outlier')
ax.legend()
plt.show()

# %% [markdown]
# ### Covariance VS Correlation
#
# #### Covariance
# - Use to consider if 2 parameters are correlated or not
#
# $$
# COV(X, Y) = \frac{{{\sum}^n}_{i=1}({X}_i - \bar{X})({Y}_i - \bar{Y})}{n - 1}
# $$
#
# #### Correlation
# - Use to consider how much for correlation between 2 parameters
#
# $$
# COR(X, Y) = \frac{COV(X, Y)}{{\sigma}_X{\sigma}_Y}
# $$

# %%
# load csv files to dataframes

ais = pd.read_csv('Data/SET50_download_r2/ADVANC.BK.csv', index_col = 0)
ais.set_index(pd.to_datetime(ais.index), inplace = True)

true = pd.read_csv('Data/SET50_download_r2/TRUE.BK.csv', index_col = 0)
true.set_index(pd.to_datetime(ais.index), inplace = True)

# %%
# setting

start = '2015'
end = '2020'

# %%
ais = ais[start:end]['Close']
true = true[start:end]['Close']

# %%
np.cov(ais, true)
# Out:
# array([[697.87839551,  31.65727831],
#        [ 31.65727831,   6.1125681 ]])

# %%
np.corrcoef(ais, true)
# Out:
# array([[1.        , 0.48469869],
#        [0.48469869, 1.        ]])

# %%
# plot 

plt.rcParams['figure.figsize'] = (10.0, 5.0)

plt.scatter(ais, true, s = 100)

plt.xlabel("AIS")
plt.ylabel("TRUE")

print(f'Covariance: {np.cov(ais, true)[0,1]:.4f}')
print(f'Correlation: {np.corrcoef(ais, true)[0,1]:.4f}')

plt.show()
# Out:
# Covariance: 31.6573
# Correlation: 0.4847

# %%
# return

ais_pct = ais.pct_change()
ais_pct.dropna(inplace = True)

true_pct = true.pct_change()
true_pct.dropna(inplace = True)

# %%
np.cov(ais_pct, true_pct)
# Out:
# array([[0.00025594, 0.00016071],
#        [0.00016071, 0.00052526]])

# %%
np.corrcoef(ais_pct, true_pct)
# Out:
# array([[1.        , 0.43831958],
#        [0.43831958, 1.        ]])

# %%
# plot 

plt.rcParams['figure.figsize'] = (10.0, 5.0)

plt.scatter(ais, true, s = 100)

plt.xlabel("AIS")
plt.ylabel("TRUE")

print(f'Covariance: {np.cov(ais_pct, true_pct)[0,1]:.4f}')
print(f'Correlation: {np.corrcoef(ais_pct, true_pct)[0,1]:.4f}')

plt.show()
# Out:
# Covariance: 0.0002
# Correlation: 0.4383

# %%
sns.jointplot(x = ais_pct, y = true_pct, kind = 'reg', height = 10);
print(f'Correlation: {np.corrcoef(ais_pct, true_pct)[0,1]:.4f}')
# Out:
# Correlation: 0.4383

# %%
# multiple stocks

stock_list = ['BBL.BK', 'KBANK.BK', 'KTB.BK', 'KTC.BK', 'LH.BK', 'SCB.BK']

bank_port = pd.DataFrame() # create empty dataframe

# %%
for s in range(0, len(stock_list)):
    bank_port[s] = pd.read_csv(f'Data/SET50_download_r2/{stock_list[s]}.csv', index_col = 0)['2018':'2023']['Close']

# %%
bank_port.head()
# Out:
#                 0      1          2          3     4   5
# Date
# 2018-01-03  205.0  237.0  19.400000  18.450001  10.6 NaN
# 2018-01-04  205.0  242.0  19.700001  18.100000  10.5 NaN
# 2018-01-05  206.0  241.0  19.900000  17.100000  10.6 NaN
# 2018-01-08  207.0  241.0  19.900000  17.650000  10.6 NaN
# 2018-01-09  208.0  235.0  20.500000  17.600000  10.7 NaN

# %%
bank_port.shape
# Out:
# (1214, 6)

# %%
bank_port.columns = stock_list
bank_port.dropna(inplace = True)
bank_port.head()
# Out:
#             BBL.BK  KBANK.BK  KTB.BK  KTC.BK  LH.BK  SCB.BK
# Date
# 2022-04-20   137.0     157.5    13.1   59.25   9.35    81.5
# 2022-04-27   131.0     151.5    14.7   57.00   9.50   114.0
# 2022-04-28   131.0     153.5    15.2   57.25   9.50   112.5
# 2022-04-29   130.5     153.0    15.2   57.75   9.55   115.0
# 2022-05-03   130.0     151.0    14.9   57.50   9.45   117.5

# %%
bank_port.shape
# Out:
# (166, 6)

# %%
bank_port.plot();

# %%
bank_port_rets = bank_port.pct_change()
bank_port_rets
# Out:
#               BBL.BK  KBANK.BK    KTB.BK    KTC.BK     LH.BK    SCB.BK
# Date
# 2022-04-20       NaN       NaN       NaN       NaN       NaN       NaN
# 2022-04-27 -0.043796 -0.038095  0.122137 -0.037975  0.016043  0.398773
# 2022-04-28  0.000000  0.013201  0.034014  0.004386  0.000000 -0.013158
# 2022-04-29 -0.003817 -0.003257  0.000000  0.008734  0.005263  0.022222
# 2022-05-03 -0.003831 -0.013072 -0.019737 -0.004329 -0.010471  0.021739
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-26  0.000000  0.003472  0.000000  0.000000  0.000000 -0.004762
# 2022-12-27  0.006873  0.006920 -0.005587  0.004237  0.010152  0.009569
# 2022-12-28  0.003413  0.003436  0.000000  0.004219  0.005025  0.004739
# 2022-12-29  0.003401  0.006849  0.000000  0.000000  0.010000  0.004717
# 2022-12-30  0.003390  0.003401 -0.005618 -0.008403 -0.019802  0.004695
#
# [166 rows x 6 columns]

# %%
bank_port_rets.dropna(inplace = True)

# %%
bank_port_rets
# Out:
#               BBL.BK  KBANK.BK    KTB.BK    KTC.BK     LH.BK    SCB.BK
# Date
# 2022-04-27 -0.043796 -0.038095  0.122137 -0.037975  0.016043  0.398773
# 2022-04-28  0.000000  0.013201  0.034014  0.004386  0.000000 -0.013158
# 2022-04-29 -0.003817 -0.003257  0.000000  0.008734  0.005263  0.022222
# 2022-05-03 -0.003831 -0.013072 -0.019737 -0.004329 -0.010471  0.021739
# 2022-05-05 -0.007692 -0.023179 -0.006711  0.000000 -0.047619 -0.017021
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-26  0.000000  0.003472  0.000000  0.000000  0.000000 -0.004762
# 2022-12-27  0.006873  0.006920 -0.005587  0.004237  0.010152  0.009569
# 2022-12-28  0.003413  0.003436  0.000000  0.004219  0.005025  0.004739
# 2022-12-29  0.003401  0.006849  0.000000  0.000000  0.010000  0.004717
# 2022-12-30  0.003390  0.003401 -0.005618 -0.008403 -0.019802  0.004695
#
# [165 rows x 6 columns]

# %%
bank_port_rets.cov() # covariance
# Out:
#             BBL.BK  KBANK.BK    KTB.BK    KTC.BK     LH.BK    SCB.BK
# BBL.BK    0.000112  0.000081  0.000032  0.000033  0.000022 -0.000002
# KBANK.BK  0.000081  0.000123  0.000020  0.000030  0.000020  0.000012
# KTB.BK    0.000032  0.000020  0.000226  0.000009  0.000046  0.000385
# KTC.BK    0.000033  0.000030  0.000009  0.000126  0.000047 -0.000033
# LH.BK     0.000022  0.000020  0.000046  0.000047  0.000129  0.000079
# SCB.BK   -0.000002  0.000012  0.000385 -0.000033  0.000079  0.001224

# %%
bank_port_rets.corr() # correlation
# Out:
#             BBL.BK  KBANK.BK    KTB.BK    KTC.BK     LH.BK    SCB.BK
# BBL.BK    1.000000  0.689466  0.199548  0.277774  0.185397 -0.004878
# KBANK.BK  0.689466  1.000000  0.118678  0.244403  0.154405  0.030739
# KTB.BK    0.199548  0.118678  1.000000  0.051769  0.270400  0.731906
# KTC.BK    0.277774  0.244403  0.051769  1.000000  0.368538 -0.082737
# LH.BK     0.185397  0.154405  0.270400  0.368538  1.000000  0.198907
# SCB.BK   -0.004878  0.030739  0.731906 -0.082737  0.198907  1.000000

# %%
# plot

sns.pairplot(bank_port_rets)

# %%
sns.pairplot(bank_port_rets, kind = 'reg');

# %%
sns.jointplot(x = 'BBL.BK', y = 'KBANK.BK', data = bank_port_rets, kind = 'reg', height = 5);

# %%
# heatmap

sns.heatmap(bank_port_rets.corr(), annot = True);

# %% [markdown]
# ### Autocorrelation

# %%
import statsmodels.tsa.api as smt

# %%
ais.head()
# Out:
# Date
# 2015-01-05    249.0
# 2015-01-06    247.0
# 2015-01-07    253.0
# 2015-01-08    250.0
# 2015-01-09    248.0
# Name: Close, dtype: float64

# %%
n_lag = 20

smt.graphics.plot_acf(ais, lags = n_lag);

# %%
ais.index
# Out:
# DatetimeIndex(['2015-01-05', '2015-01-06', '2015-01-07', '2015-01-08',
#                '2015-01-09', '2015-01-12', '2015-01-13', '2015-01-14',
#                '2015-01-15', '2015-01-16',
#                ...
#                '2020-12-17', '2020-12-18', '2020-12-21', '2020-12-22',
#                '2020-12-23', '2020-12-24', '2020-12-25', '2020-12-28',
#                '2020-12-29', '2020-12-30'],
#               dtype='datetime64[ns]', name='Date', length=1462, freq=None)

# %%
ais["2020-06"].plot(label = "Close")

ais.shift(1)["2020-06"].plot(label = "lag 1")
ais.shift(2)["2020-06"].plot(label = "lag 2")

plt.legend()
plt.show()

# %%
smt.graphics.plot_acf(ais_pct, lags = n_lag)
plt.show()

# %% [markdown]
# ### Violin and QQ Plot (normal or not?)

# %%
# random small number

np.random.seed(10)

mu, sigma = 0, 0.3

stock_random = np.random.normal(mu, sigma, 20)
stock_random
# Out:
# array([ 0.39947595,  0.21458369, -0.46362009, -0.00251515,  0.18640079,
#        -0.21602567,  0.07965348,  0.03256456,  0.00128743, -0.05238006,
#         0.12990786,  0.36091121, -0.2895197 ,  0.30848222,  0.06858904,
#         0.13354128, -0.34098066,  0.04054106,  0.4453611 , -0.32394147])

# %%
len(stock_random)
# Out:
# 20

# %%
plt.rcParams['figure.figsize'] = (10.0, 5.0)

sns.histplot(stock_random, kde = True);

# %%
sns.violinplot(data = stock_random);

# %%
# apply scipy

from scipy import stats

# %%
stats.probplot(stock_random, dist = 'norm', plot = plt);

# %%
# random larg number

np.random.seed(10)
mu, sigma = 0, 0.2

stock_random2 = np.random.normal(mu, sigma, 10000)
stock_random2
# Out:
# array([ 0.2663173 ,  0.14305579, -0.30908006, ...,  0.12947556,
#         0.25014784,  0.23258884])

# %%
len(stock_random2)
# Out:
# 10000

# %%
plt.rcParams['figure.figsize'] = (10.0, 5.0)

sns.histplot(stock_random2, kde = True);

# %%
sns.violinplot(data = stock_random2);

# %%
stats.probplot(stock_random2, dist = 'norm', plot = plt);

# %%
# apply to stock

ais_pct
# Out:
# Date
# 2015-01-06   -0.008032
# 2015-01-07    0.024291
# 2015-01-08   -0.011858
# 2015-01-09   -0.008000
# 2015-01-12   -0.004032
#                 ...
# 2020-12-24    0.005634
# 2020-12-25    0.002801
# 2020-12-28   -0.011173
# 2020-12-29    0.008475
# 2020-12-30   -0.014006
# Name: Close, Length: 1461, dtype: float64

# %%
sns.violinplot(data = ais_pct);

# %%
stats.probplot(ais_pct, dist = 'norm', plot = plt);

# %%
# plot

plt.subplot2grid((2, 2), (0, 0))
stats.probplot(stock_random, dist = "norm", plot = plt)

plt.subplot2grid((2, 2), (0, 1))
sns.violinplot(data = stock_random)

plt.subplot2grid((2, 2), (1, 0))
stats.probplot(ais_pct, dist = "norm", plot = plt)

plt.subplot2grid((2, 2), (1, 1))
sns.violinplot(data= ais_pct)

plt.tight_layout()
plt.show()
