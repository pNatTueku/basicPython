# %%
# import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# check files in a directory

# !ls
# Out:
# 220px-Stock_Price_Listing_Numbers_on_a_Korean_Newspaper.jpg
# 3_axis_v1.png
# 3_axis_v2.png
# 3_axis_v3.png
# Data
# Iris.csv
# README.md
# Titanic-Dataset.csv
# basicNumpy.ipynb
# basicPandas.ipynb
# basicPandas02.ipynb
# basicPandas03.ipynb
# basic_NLP.ipynb
# basic_api.ipynb
# basic_api_data_go_th.ipynb
# basic_assert.ipynb
# basic_calculated_col_by_map.ipynb
# basic_class.ipynb
# basic_classification_binary.ipynb
# basic_classification_binary_lightGBM_titanic.ipynb
# basic_classification_model_comparision.ipynb
# basic_classification_multiple.ipynb
# basic_classification_sklearn_iris.ipynb
# basic_classification_tree.ipynb
# basic_classifier_REF_feature_importances.ipynb
# basic_classifier_tree_feature_importances.ipynb
# basic_clean_unique_values_using_threshold.ipynb
# basic_combine_csv_files_01.ipynb
# basic_combine_csv_files_02.ipynb
# basic_combine_csv_files_03.ipynb
# basic_combine_csv_files_04.ipynb
# basic_combine_csv_files_05.ipynb
# ...

# %%
# !ls "Data"
# Out:
# DWJ_download      SET50_download    SET50_download_r2

# %%
# !ls 'Data/DWJ_download'
# Out:
# AAPL.csv CAT.csv  DIS.csv  HON.csv  JPM.csv  MRK.csv  TRV.csv  WBA.csv
# AMGN.csv CRM.csv  DOW.csv  IBM.csv  KO.csv   MSFT.csv UNH.csv  WMT.csv
# AXP.csv  CSCO.csv GS.csv   INTC.csv MCD.csv  NKE.csv  V.csv
# BA.csv   CVX.csv  HD.csv   JNJ.csv  MMM.csv  PG.csv   VZ.csv

# %%
# read a csv file to a dataframe

df = pd.read_csv("Data/DWJ_download/IBM.csv")
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close  Volume
# 0  1962-01-02  7.374124  7.374124  7.291268  7.291268   1.541711  407940
# 1  1962-01-03  7.291268  7.355003  7.291268  7.355003   1.555187  305955
# 2  1962-01-04  7.355003  7.355003  7.278521  7.281708   1.539689  274575
# 3  1962-01-05  7.272148  7.272148  7.125558  7.138305   1.509367  384405
# 4  1962-01-08  7.131931  7.131931  6.947100  7.004461   1.481066  572685

# %%
df = pd.read_csv("Data/DWJ_download/IBM.csv", index_col = 0)
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 1962-01-02  7.374124  7.374124  7.291268  7.291268   1.541711  407940
# 1962-01-03  7.291268  7.355003  7.291268  7.355003   1.555187  305955
# 1962-01-04  7.355003  7.355003  7.278521  7.281708   1.539689  274575
# 1962-01-05  7.272148  7.272148  7.125558  7.138305   1.509367  384405
# 1962-01-08  7.131931  7.131931  6.947100  7.004461   1.481066  572685

# %%
# inspect our data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15640 entries, 1962-01-02 to 2024-02-20
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       15640 non-null  float64
#  1   High       15640 non-null  float64
#  2   Low        15640 non-null  float64
#  3   Close      15640 non-null  float64
#  4   Adj Close  15640 non-null  float64
#  5   Volume     15640 non-null  int64
# dtypes: float64(5), int64(1)
# memory usage: 855.3+ KB

# %%
df.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  15640.000000  15640.000000  15640.000000  15640.000000  15640.000000
# mean      62.128235     62.700827     61.586259     62.148778     38.715946
# std       56.152391     56.607709     55.730034     56.178938     43.095089
# min        3.900574      4.098152      3.824092      3.900574      0.825004
# 25%       15.625000     15.726577     15.504003     15.625000      4.167827
# 50%       29.278202     29.517208     29.024260     29.248327     11.901270
# 75%      112.332695    113.663958    110.939295    112.237091     64.635639
# max      205.908218    206.405350    204.875717    206.309753    188.709549
#
#              Volume
# count  1.564000e+04
# mean   5.088944e+06
# std    4.613708e+06
# min    0.000000e+00
# 25%    1.529644e+06
# 50%    4.308944e+06
# 75%    7.051348e+06
# max    7.263916e+07

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-02-13  184.279999  184.770004  182.360001  183.699997  183.699997
# 2024-02-14  185.000000  185.000000  182.259995  183.570007  183.570007
# 2024-02-15  183.619995  186.979996  183.619995  186.869995  186.869995
# 2024-02-16  186.630005  188.949997  185.949997  187.639999  187.639999
# 2024-02-20  187.639999  188.759995  183.059998  183.440002  183.440002
#
#              Volume
# Date
# 2024-02-13  4290500
# 2024-02-14  3173400
# 2024-02-15  4714300
# 2024-02-16  4841900
# 2024-02-20  4243975

# %%
df.pct_change()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 1962-01-02       NaN       NaN       NaN       NaN        NaN       NaN
# 1962-01-03 -0.011236 -0.002593  0.000000  0.008741   0.008741 -0.250000
# 1962-01-04  0.008741  0.000000 -0.001748 -0.009965  -0.009965 -0.102564
# 1962-01-05 -0.011265 -0.011265 -0.021016 -0.019694  -0.019693  0.400000
# 1962-01-08 -0.019281 -0.019281 -0.025045 -0.018750  -0.018751  0.489796
# ...              ...       ...       ...       ...        ...       ...
# 2024-02-13 -0.008714 -0.009170 -0.009075 -0.013214  -0.013214 -0.091765
# 2024-02-14  0.003907  0.001245 -0.000548 -0.000708  -0.000708 -0.260366
# 2024-02-15 -0.007459  0.010703  0.007462  0.017977   0.017977  0.485568
# 2024-02-16  0.016393  0.010536  0.012689  0.004121   0.004121  0.027067
# 2024-02-20  0.005412 -0.001006 -0.015542 -0.022383  -0.022383 -0.123490
#
# [15640 rows x 6 columns]

# %%
df.pct_change().describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  15639.000000  15639.000000  15639.000000  15639.000000  15639.000000
# mean       0.000327      0.000303      0.000317      0.000332      0.000431
# std        0.015509      0.013833      0.014833      0.015875      0.015842
# min       -0.148148     -0.177446     -0.242424     -0.235185     -0.235185
# 25%       -0.007620     -0.006431     -0.006645     -0.007788     -0.007677
# 50%        0.000000      0.000000      0.000385      0.000000      0.000000
# 75%        0.008020      0.006607      0.007246      0.008111      0.008157
# max        0.162003      0.156364      0.166919      0.131636      0.131637
#
#              Volume
# count  1.563900e+04
# mean            inf
# std             NaN
# min   -1.000000e+00
# 25%   -2.120697e-01
# 50%   -1.321972e-02
# 75%    2.522437e-01
# max             inf

# %%
df.pct_change().describe() * 100
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  1.563900e+06  1.563900e+06  1.563900e+06  1.563900e+06  1.563900e+06
# mean   3.272263e-02  3.028130e-02  3.166440e-02  3.324583e-02  4.312953e-02
# std    1.550877e+00  1.383282e+00  1.483310e+00  1.587536e+00  1.584205e+00
# min   -1.481481e+01 -1.774461e+01 -2.424242e+01 -2.351852e+01 -2.351850e+01
# 25%   -7.619671e-01 -6.430915e-01 -6.644514e-01 -7.787735e-01 -7.677007e-01
# 50%    0.000000e+00  0.000000e+00  3.846527e-02  0.000000e+00  0.000000e+00
# 75%    8.020433e-01  6.607381e-01  7.246347e-01  8.110541e-01  8.156741e-01
# max    1.620030e+01  1.563637e+01  1.669190e+01  1.316364e+01  1.316366e+01
#
#              Volume
# count  1.563900e+06
# mean            inf
# std             NaN
# min   -1.000000e+02
# 25%   -2.120697e+01
# 50%   -1.321972e+00
# 75%    2.522437e+01
# max             inf

# %%
# 5 day's % change

df.pct_change(5).head()
# Out:
#             Open  High  Low  Close  Adj Close  Volume
# Date
# 1962-01-02   NaN   NaN  NaN    NaN        NaN     NaN
# 1962-01-03   NaN   NaN  NaN    NaN        NaN     NaN
# 1962-01-04   NaN   NaN  NaN    NaN        NaN     NaN
# 1962-01-05   NaN   NaN  NaN    NaN        NaN     NaN
# 1962-01-08   NaN   NaN  NaN    NaN        NaN     NaN

# %%
df.pct_change(5).head(10)
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 1962-01-02       NaN       NaN       NaN       NaN        NaN       NaN
# 1962-01-03       NaN       NaN       NaN       NaN        NaN       NaN
# 1962-01-04       NaN       NaN       NaN       NaN        NaN       NaN
# 1962-01-05       NaN       NaN       NaN       NaN        NaN       NaN
# 1962-01-08       NaN       NaN       NaN       NaN        NaN       NaN
# 1962-01-09 -0.045808 -0.026793 -0.034965 -0.027972  -0.027972  0.269231
# 1962-01-10 -0.026224 -0.030329 -0.026224 -0.034662  -0.034662  0.025641
# 1962-01-11 -0.032062 -0.024263 -0.021891 -0.014442  -0.014441  0.228571
# 1962-01-12 -0.011394 -0.004382  0.008945  0.007143   0.007143  0.204082
# 1962-01-15  0.011618  0.014745  0.038532  0.030937   0.030938 -0.534247

# %%
df.pct_change(21).describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  15619.000000  15619.000000  15619.000000  15619.000000  15619.000000
# mean       0.006947      0.006874      0.007056      0.006990      0.009083
# std        0.071614      0.070595      0.073079      0.072161      0.072231
# min       -0.373676     -0.352887     -0.391561     -0.369197     -0.369197
# 25%       -0.035019     -0.035011     -0.035459     -0.035288     -0.033060
# 50%        0.005267      0.005070      0.005707      0.005255      0.007519
# 75%        0.047610      0.046749      0.048547      0.047766      0.050301
# max        0.444346      0.410935      0.464945      0.457597      0.457596
#
#              Volume
# count  1.561900e+04
# mean            inf
# std             NaN
# min   -1.000000e+00
# 25%   -2.816243e-01
# 50%   -8.620690e-03
# 75%    4.075647e-01
# max             inf

# %%
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 1962-01-02  7.374124  7.374124  7.291268  7.291268   1.541711  407940
# 1962-01-03  7.291268  7.355003  7.291268  7.355003   1.555187  305955
# 1962-01-04  7.355003  7.355003  7.278521  7.281708   1.539689  274575
# 1962-01-05  7.272148  7.272148  7.125558  7.138305   1.509367  384405
# 1962-01-08  7.131931  7.131931  6.947100  7.004461   1.481066  572685

# %%
# select data

df.iloc[0]
# Out:
# Open              7.374124
# High              7.374124
# Low               7.291268
# Close             7.291268
# Adj Close         1.541711
# Volume       407940.000000
# Name: 1962-01-02, dtype: float64

# %%
df.iloc[3]
# Out:
# Open              7.272148
# High              7.272148
# Low               7.125558
# Close             7.138305
# Adj Close         1.509367
# Volume       384405.000000
# Name: 1962-01-05, dtype: float64

# %%
df.iloc[-1]
# Out:
# Open         1.876400e+02
# High         1.887600e+02
# Low          1.830600e+02
# Close        1.834400e+02
# Adj Close    1.834400e+02
# Volume       4.243975e+06
# Name: 2024-02-20, dtype: float64

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-02-13  184.279999  184.770004  182.360001  183.699997  183.699997
# 2024-02-14  185.000000  185.000000  182.259995  183.570007  183.570007
# 2024-02-15  183.619995  186.979996  183.619995  186.869995  186.869995
# 2024-02-16  186.630005  188.949997  185.949997  187.639999  187.639999
# 2024-02-20  187.639999  188.759995  183.059998  183.440002  183.440002
#
#              Volume
# Date
# 2024-02-13  4290500
# 2024-02-14  3173400
# 2024-02-15  4714300
# 2024-02-16  4841900
# 2024-02-20  4243975

# %%
df.iloc[:5]
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 1962-01-02  7.374124  7.374124  7.291268  7.291268   1.541711  407940
# 1962-01-03  7.291268  7.355003  7.291268  7.355003   1.555187  305955
# 1962-01-04  7.355003  7.355003  7.278521  7.281708   1.539689  274575
# 1962-01-05  7.272148  7.272148  7.125558  7.138305   1.509367  384405
# 1962-01-08  7.131931  7.131931  6.947100  7.004461   1.481066  572685

# %%
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 1962-01-02  7.374124  7.374124  7.291268  7.291268   1.541711  407940
# 1962-01-03  7.291268  7.355003  7.291268  7.355003   1.555187  305955
# 1962-01-04  7.355003  7.355003  7.278521  7.281708   1.539689  274575
# 1962-01-05  7.272148  7.272148  7.125558  7.138305   1.509367  384405
# 1962-01-08  7.131931  7.131931  6.947100  7.004461   1.481066  572685

# %%
df.loc['1962-01-04']
# Out:
# Open              7.355003
# High              7.355003
# Low               7.278521
# Close             7.281708
# Adj Close         1.539689
# Volume       274575.000000
# Name: 1962-01-04, dtype: float64

# %%
df.loc['1962-01-04' : '1962-01-08']
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 1962-01-04  7.355003  7.355003  7.278521  7.281708   1.539689  274575
# 1962-01-05  7.272148  7.272148  7.125558  7.138305   1.509367  384405
# 1962-01-08  7.131931  7.131931  6.947100  7.004461   1.481066  572685

# %%
# acces a column

df.Low
# Out:
# Date
# 1962-01-02      7.291268
# 1962-01-03      7.291268
# 1962-01-04      7.278521
# 1962-01-05      7.125558
# 1962-01-08      6.947100
#                  ...
# 2024-02-13    182.360001
# 2024-02-14    182.259995
# 2024-02-15    183.619995
# 2024-02-16    185.949997
# 2024-02-20    183.059998
# Name: Low, Length: 15640, dtype: float64

# %%
df.Open
# Out:
# Date
# 1962-01-02      7.374124
# 1962-01-03      7.291268
# 1962-01-04      7.355003
# 1962-01-05      7.272148
# 1962-01-08      7.131931
#                  ...
# 2024-02-13    184.279999
# 2024-02-14    185.000000
# 2024-02-15    183.619995
# 2024-02-16    186.630005
# 2024-02-20    187.639999
# Name: Open, Length: 15640, dtype: float64

# %%
df.Open.iloc[-1]
# Out:
# 187.63999938964844

# %%
df.Open.iloc[:10]
# Out:
# Date
# 1962-01-02    7.374124
# 1962-01-03    7.291268
# 1962-01-04    7.355003
# 1962-01-05    7.272148
# 1962-01-08    7.131931
# 1962-01-09    7.036329
# 1962-01-10    7.100064
# 1962-01-11    7.119184
# 1962-01-12    7.189293
# 1962-01-15    7.214786
# Name: Open, dtype: float64

# %%
# get columns and data

df[['Adj Close', 'Close']].head()
# Out:
#             Adj Close     Close
# Date
# 1962-01-02   1.541711  7.291268
# 1962-01-03   1.555187  7.355003
# 1962-01-04   1.539689  7.281708
# 1962-01-05   1.509367  7.138305
# 1962-01-08   1.481066  7.004461

# %%
df[['Adj Close', 'Volume']].iloc[:4]
# Out:
#             Adj Close  Volume
# Date
# 1962-01-02   1.541711  407940
# 1962-01-03   1.555187  305955
# 1962-01-04   1.539689  274575
# 1962-01-05   1.509367  384405

# %%
df[['Adj Close', 'Volume']][:4]
# Out:
#             Adj Close  Volume
# Date
# 1962-01-02   1.541711  407940
# 1962-01-03   1.555187  305955
# 1962-01-04   1.539689  274575
# 1962-01-05   1.509367  384405

# %%
df[['Adj Close', 'Volume']]['1962-01-04':'1962-01-10']
# Out:
#             Adj Close  Volume
# Date
# 1962-01-04   1.539689  274575
# 1962-01-05   1.509367  384405
# 1962-01-08   1.481066  572685
# 1962-01-09   1.498586  517770
# 1962-01-10   1.501280  313800

# %%
# get data using condition

df_pct = df.pct_change()
df_pct.head(10)
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 1962-01-02       NaN       NaN       NaN       NaN        NaN       NaN
# 1962-01-03 -0.011236 -0.002593  0.000000  0.008741   0.008741 -0.250000
# 1962-01-04  0.008741  0.000000 -0.001748 -0.009965  -0.009965 -0.102564
# 1962-01-05 -0.011265 -0.011265 -0.021016 -0.019694  -0.019693  0.400000
# 1962-01-08 -0.019281 -0.019281 -0.025045 -0.018750  -0.018751  0.489796
# 1962-01-09 -0.013405  0.006256  0.012844  0.011829   0.011829 -0.095890
# 1962-01-10  0.009058 -0.006217  0.009058  0.001799   0.001798 -0.393939
# 1962-01-11  0.002693  0.006256  0.002693  0.010772   0.010773  0.075000
# 1962-01-12  0.009848  0.008881  0.009848  0.001776   0.001776  0.372093
# 1962-01-15  0.003546 -0.000440  0.003546  0.004433   0.004432 -0.423729

# %%
df_pct['Volume'] < 0
# Out:
# Date
# 1962-01-02    False
# 1962-01-03     True
# 1962-01-04     True
# 1962-01-05    False
# 1962-01-08    False
#               ...
# 2024-02-13     True
# 2024-02-14     True
# 2024-02-15    False
# 2024-02-16    False
# 2024-02-20     True
# Name: Volume, Length: 15640, dtype: bool

# %%
df_pct[df_pct['Volume'] < 0]
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 1962-01-03 -0.011236 -0.002593  0.000000  0.008741   0.008741 -0.250000
# 1962-01-04  0.008741  0.000000 -0.001748 -0.009965  -0.009965 -0.102564
# 1962-01-09 -0.013405  0.006256  0.012844  0.011829   0.011829 -0.095890
# 1962-01-10  0.009058 -0.006217  0.009058  0.001799   0.001798 -0.393939
# 1962-01-15  0.003546 -0.000440  0.003546  0.004433   0.004432 -0.423729
# ...              ...       ...       ...       ...        ...       ...
# 2024-02-09  0.009911  0.014251  0.013003  0.010740   0.010740 -0.018717
# 2024-02-12  0.007916 -0.003740  0.000979 -0.000966  -0.000966 -0.067251
# 2024-02-13 -0.008714 -0.009170 -0.009075 -0.013214  -0.013214 -0.091765
# 2024-02-14  0.003907  0.001245 -0.000548 -0.000708  -0.000708 -0.260366
# 2024-02-20  0.005412 -0.001006 -0.015542 -0.022383  -0.022383 -0.123490
#
# [8035 rows x 6 columns]

# %%
df_pct[df_pct['Volume'] > 0]
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 1962-01-05 -0.011265 -0.011265 -0.021016 -0.019694  -0.019693  0.400000
# 1962-01-08 -0.019281 -0.019281 -0.025045 -0.018750  -0.018751  0.489796
# 1962-01-11  0.002693  0.006256  0.002693  0.010772   0.010773  0.075000
# 1962-01-12  0.009848  0.008881  0.009848  0.001776   0.001776  0.372093
# 1962-01-17 -0.014134 -0.014134 -0.018733 -0.016057  -0.016057  0.647059
# ...              ...       ...       ...       ...        ...       ...
# 2024-02-05 -0.008498 -0.008592 -0.012714 -0.012756  -0.012756  0.080262
# 2024-02-07 -0.001144 -0.003574 -0.002240  0.001799   0.001799  0.450503
# 2024-02-08 -0.003873  0.002880 -0.006242  0.003374   0.012522  0.066099
# 2024-02-15 -0.007459  0.010703  0.007462  0.017977   0.017977  0.485568
# 2024-02-16  0.016393  0.010536  0.012689  0.004121   0.004121  0.027067
#
# [7568 rows x 6 columns]

# %%
condition = df_pct['Volume'] > 0
condition
# Out:
# Date
# 1962-01-02    False
# 1962-01-03    False
# 1962-01-04    False
# 1962-01-05     True
# 1962-01-08     True
#               ...
# 2024-02-13    False
# 2024-02-14    False
# 2024-02-15     True
# 2024-02-16     True
# 2024-02-20    False
# Name: Volume, Length: 15640, dtype: bool

# %%
df_pct['Volume'][condition]
# Out:
# Date
# 1962-01-05    0.400000
# 1962-01-08    0.489796
# 1962-01-11    0.075000
# 1962-01-12    0.372093
# 1962-01-17    0.647059
#                 ...
# 2024-02-05    0.080262
# 2024-02-07    0.450503
# 2024-02-08    0.066099
# 2024-02-15    0.485568
# 2024-02-16    0.027067
# Name: Volume, Length: 7568, dtype: float64

# %%
len(df_pct)
# Out:
# 15640

# %%
condition1 = df_pct['Volume'] > 0
condition2 = df_pct['Close'] < 0

# %%
df_pct[condition1 & condition2]
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 1962-01-05 -0.011265 -0.011265 -0.021016 -0.019694  -0.019693  0.400000
# 1962-01-08 -0.019281 -0.019281 -0.025045 -0.018750  -0.018751  0.489796
# 1962-01-17 -0.014134 -0.014134 -0.018733 -0.016057  -0.016057  0.647059
# 1962-01-23 -0.002258 -0.010733 -0.010870 -0.009955  -0.009954  0.351351
# 1962-01-29 -0.005055 -0.001831 -0.016636 -0.017090  -0.017089  1.363636
# ...              ...       ...       ...       ...        ...       ...
# 2024-01-03 -0.011239 -0.009554 -0.002368 -0.008669  -0.008669  0.068261
# 2024-01-05 -0.001935 -0.007787 -0.009365 -0.010568  -0.010568  0.307410
# 2024-01-24  0.010758  0.004827  0.002435 -0.000058  -0.000058  1.283871
# 2024-01-31 -0.003516 -0.005301 -0.019436 -0.022409  -0.022409  0.940089
# 2024-02-05 -0.008498 -0.008592 -0.012714 -0.012756  -0.012756  0.080262
#
# [3690 rows x 6 columns]

# %%
condition3 = df_pct['Open'] > 0.1
print(f"there are {df_pct[condition3].shape[0]} rows meet this condition\n")
print(df_pct[condition3])
# Out:
# there are 6 rows meet this condition
#
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 1975-01-28  0.100537  0.154259  0.100537  0.103607   0.103606       inf
# 1997-10-29  0.123595  0.023140  0.104372 -0.011321  -0.011321 -0.316500
# 1999-04-22  0.162003  0.156364  0.166919  0.131636   0.131637  1.976067
# 2001-01-04  0.131343  0.050000  0.106716 -0.015192  -0.015192  0.207566
# 2002-10-11  0.134492  0.093023  0.138678  0.110108   0.110108  0.409073
# 2002-10-15  0.100910  0.073354  0.081898  0.079786   0.079786  0.842227

# %%
df_pct[condition1 | condition3] # OR
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 1962-01-05 -0.011265 -0.011265 -0.021016 -0.019694  -0.019693  0.400000
# 1962-01-08 -0.019281 -0.019281 -0.025045 -0.018750  -0.018751  0.489796
# 1962-01-11  0.002693  0.006256  0.002693  0.010772   0.010773  0.075000
# 1962-01-12  0.009848  0.008881  0.009848  0.001776   0.001776  0.372093
# 1962-01-17 -0.014134 -0.014134 -0.018733 -0.016057  -0.016057  0.647059
# ...              ...       ...       ...       ...        ...       ...
# 2024-02-05 -0.008498 -0.008592 -0.012714 -0.012756  -0.012756  0.080262
# 2024-02-07 -0.001144 -0.003574 -0.002240  0.001799   0.001799  0.450503
# 2024-02-08 -0.003873  0.002880 -0.006242  0.003374   0.012522  0.066099
# 2024-02-15 -0.007459  0.010703  0.007462  0.017977   0.017977  0.485568
# 2024-02-16  0.016393  0.010536  0.012689  0.004121   0.004121  0.027067
#
# [7569 rows x 6 columns]

# %%
df_pct[condition1 & condition3] # AND
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 1975-01-28  0.100537  0.154259  0.100537  0.103607   0.103606       inf
# 1999-04-22  0.162003  0.156364  0.166919  0.131636   0.131637  1.976067
# 2001-01-04  0.131343  0.050000  0.106716 -0.015192  -0.015192  0.207566
# 2002-10-11  0.134492  0.093023  0.138678  0.110108   0.110108  0.409073
# 2002-10-15  0.100910  0.073354  0.081898  0.079786   0.079786  0.842227

# %%
condition4 = np.abs(df_pct['Adj Close']) > 0.2
condition4
# Out:
# Date
# 1962-01-02    False
# 1962-01-03    False
# 1962-01-04    False
# 1962-01-05    False
# 1962-01-08    False
#               ...
# 2024-02-13    False
# 2024-02-14    False
# 2024-02-15    False
# 2024-02-16    False
# 2024-02-20    False
# Name: Adj Close, Length: 15640, dtype: bool

# %%
print(f'There are {df_pct[condition4].shape[0]} rows meet condition 4')
# Out:
# There are 1 rows meet condition 4

# %%
print(f'There are {df_pct[condition4].shape[0]} rows meet condition 4')
print(df_pct[condition4])
# Out:
# There are 1 rows meet condition 4
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 1987-10-19 -0.042553 -0.023009 -0.242424 -0.235185  -0.235185  0.366431

# %%
# Resampling - Change data frequency such as day to month using average, std, etc.

df.index
# Out:
# Index(['1962-01-02', '1962-01-03', '1962-01-04', '1962-01-05', '1962-01-08',
#        '1962-01-09', '1962-01-10', '1962-01-11', '1962-01-12', '1962-01-15',
#        ...
#        '2024-02-06', '2024-02-07', '2024-02-08', '2024-02-09', '2024-02-12',
#        '2024-02-13', '2024-02-14', '2024-02-15', '2024-02-16', '2024-02-20'],
#       dtype='object', name='Date', length=15640)

# %%
# change object to datetime

pd.to_datetime(df.index)
# Out:
# DatetimeIndex(['1962-01-02', '1962-01-03', '1962-01-04', '1962-01-05',
#                '1962-01-08', '1962-01-09', '1962-01-10', '1962-01-11',
#                '1962-01-12', '1962-01-15',
#                ...
#                '2024-02-06', '2024-02-07', '2024-02-08', '2024-02-09',
#                '2024-02-12', '2024-02-13', '2024-02-14', '2024-02-15',
#                '2024-02-16', '2024-02-20'],
#               dtype='datetime64[ns]', name='Date', length=15640, freq=None)

# %%
df.index
# Out:
# Index(['1962-01-02', '1962-01-03', '1962-01-04', '1962-01-05', '1962-01-08',
#        '1962-01-09', '1962-01-10', '1962-01-11', '1962-01-12', '1962-01-15',
#        ...
#        '2024-02-06', '2024-02-07', '2024-02-08', '2024-02-09', '2024-02-12',
#        '2024-02-13', '2024-02-14', '2024-02-15', '2024-02-16', '2024-02-20'],
#       dtype='object', name='Date', length=15640)

# %%
# change object to datetime then set it as index, require inplace = True as it should be saved

df.set_index(pd.to_datetime(df.index), inplace = True)

# %%
df.index
# Out:
# DatetimeIndex(['1962-01-02', '1962-01-03', '1962-01-04', '1962-01-05',
#                '1962-01-08', '1962-01-09', '1962-01-10', '1962-01-11',
#                '1962-01-12', '1962-01-15',
#                ...
#                '2024-02-06', '2024-02-07', '2024-02-08', '2024-02-09',
#                '2024-02-12', '2024-02-13', '2024-02-14', '2024-02-15',
#                '2024-02-16', '2024-02-20'],
#               dtype='datetime64[ns]', name='Date', length=15640, freq=None)

# %%
# Resampling from day to year end frequency

df.resample(rule = 'A').mean() # aplly mean()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1962-12-31    5.523916    5.580120    5.465625    5.511460    1.165733
# 1963-12-31    5.716833    5.760527    5.688673    5.718930    1.210702
# 1964-12-31    7.118128    7.161081    7.084758    7.114558    1.507594
# 1965-12-31    7.661406    7.700980    7.626875    7.665990    1.626485
# 1966-12-31    8.225058    8.288974    8.161927    8.225583    1.747234
# ...                ...         ...         ...         ...         ...
# 2020-12-31  118.956877  120.375381  117.517930  118.929519   99.238641
# 2021-12-31  128.911291  130.018875  127.934767  128.959140  113.357896
# 2022-12-31  133.542071  134.892988  132.227729  133.637689  123.328750
# 2023-12-31  139.037480  140.016240  138.139160  139.118280  134.907453
# 2024-12-31  175.847942  177.432352  174.494999  176.057353  174.860579
#
#                   Volume
# Date
# 1962-12-31  1.529682e+06
# 1963-12-31  8.160675e+05
# ...

# %%
df.resample(rule = 'A').sum() # aplly sum()
# Out:
#                     Open          High           Low         Close  \
# Date
# 1962-12-31   1392.026773   1406.190248   1377.337468   1388.887828
# 1963-12-31   1434.925107   1445.892295   1427.856915   1435.451314
# 1964-12-31   1800.886304   1811.753502   1792.443829   1799.983263
# 1965-12-31   1930.674391   1940.646905   1921.972591   1931.829580
# 1966-12-31   2072.714501   2088.821492   2056.805683   2072.846946
# ...                  ...           ...           ...           ...
# 2020-12-31  30096.089905  30454.971329  29732.036354  30089.168213
# 2021-12-31  32485.645424  32764.756470  32239.561241  32497.703186
# 2022-12-31  33519.059921  33858.139931  33189.160057  33543.059990
# 2023-12-31  34759.369995  35004.059906  34534.789925  34779.570122
# 2024-12-31   5978.830032   6032.699951   5932.829971   5985.949997
#
#                Adj Close      Volume
# Date
# 1962-12-31    293.764685   385479765
# 1963-12-31    303.886158   204832950
# ...

# %%
df_pct.set_index(pd.to_datetime(df_pct.index), inplace = True)
df_pct.index
# Out:
# DatetimeIndex(['1962-01-02', '1962-01-03', '1962-01-04', '1962-01-05',
#                '1962-01-08', '1962-01-09', '1962-01-10', '1962-01-11',
#                '1962-01-12', '1962-01-15',
#                ...
#                '2024-02-06', '2024-02-07', '2024-02-08', '2024-02-09',
#                '2024-02-12', '2024-02-13', '2024-02-14', '2024-02-15',
#                '2024-02-16', '2024-02-20'],
#               dtype='datetime64[ns]', name='Date', length=15640, freq=None)

# %%
df_pct.resample(rule = 'A').sum() # apply sum()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 1962-12-31 -0.338931 -0.351039 -0.333718 -0.328832  -0.328136  58.425169
# 1963-12-31  0.253964  0.264239  0.260695  0.274410   0.275352  24.534549
# 1964-12-31  0.037972  0.022927  0.032452  0.022343   0.023383  28.371763
# 1965-12-31  0.203529  0.197290  0.203067  0.207386   0.208631  51.325681
# 1966-12-31  0.124273  0.132764  0.130601  0.134087   0.135330  22.104721
# ...              ...       ...       ...       ...        ...        ...
# 2020-12-31  0.002669 -0.005424 -0.000569  0.021282   0.072364  24.370142
# 2021-12-31  0.143067  0.135445  0.142825  0.132362   0.180747  21.571672
# 2022-12-31  0.076689  0.068148  0.072144  0.081751   0.129267  18.237744
# 2023-12-31  0.166236  0.165043  0.166632  0.162045   0.209987  21.890656
# 2024-12-31  0.140210  0.148556  0.121167  0.121275   0.130423   3.953523
#
# [63 rows x 6 columns]

# %%
df_pct.resample(rule = 'M').sum() # month end frequency
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 1962-01-31 -0.085646 -0.064173 -0.073908 -0.052214  -0.052214   2.039649
# 1962-02-28  0.011242 -0.008594  0.005580 -0.008643  -0.008507  16.240832
# 1962-03-31  0.002260  0.000375 -0.004554 -0.007454  -0.007453   3.383020
# 1962-04-30 -0.099226 -0.090293 -0.160044 -0.156059  -0.156059  14.146713
# 1962-05-31 -0.206473 -0.196558 -0.127357 -0.134034  -0.133882   3.721695
# ...              ...       ...       ...       ...        ...        ...
# 2023-10-31  0.008463  0.019646  0.022670  0.032360   0.032360   1.568109
# 2023-11-30  0.093837  0.092135  0.096272  0.092635   0.103868   1.373800
# 2023-12-31  0.042861  0.035135  0.037723  0.031413   0.031413   0.416747
# 2024-01-31  0.136314  0.142330  0.121016  0.121645   0.121645   4.249220
# 2024-02-29  0.003897  0.006227  0.000151 -0.000369   0.008778  -0.295698
#
# [746 rows x 6 columns]

# %%
df_pct.resample(rule = 'W').sum() # week end frequency
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 1962-01-07 -0.013760 -0.013858 -0.022764 -0.020918  -0.020918  0.047436
# 1962-01-14 -0.011087 -0.004106  0.009398  0.007426   0.007426  0.447059
# 1962-01-21 -0.019549 -0.023923 -0.030300 -0.018592  -0.018592  0.196187
# 1962-01-28 -0.016285 -0.015190 -0.010914 -0.022241  -0.022241 -0.314203
# 1962-02-04  0.019866  0.022331  0.020936  0.031486   0.031486  1.297005
# ...              ...       ...       ...       ...        ...       ...
# 2024-01-28  0.116990  0.122228  0.098127  0.093297   0.093297  2.391273
# 2024-02-04 -0.021694 -0.026192 -0.002578 -0.008300  -0.008300 -0.299337
# 2024-02-11 -0.014170 -0.000955 -0.009393  0.003103   0.012250  0.340227
# 2024-02-18  0.012042  0.009574  0.011507  0.007209   0.007209  0.093252
# 2024-02-25  0.005412 -0.001006 -0.015542 -0.022383  -0.022383 -0.123490
#
# [3243 rows x 6 columns]

# %%
df_pct.resample(rule = 'W').std() # week end frequency by applying std()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 1962-01-07  0.011542  0.005900  0.011662  0.014452   0.014451  0.340785
# 1962-01-14  0.013352  0.011876  0.015499  0.012277   0.012277  0.356507
# 1962-01-21  0.007352  0.006064  0.010269  0.009066   0.009065  0.390004
# 1962-01-28  0.006934  0.010797  0.007194  0.006672   0.006672  0.280401
# 1962-02-04  0.018954  0.016520  0.019650  0.021468   0.021468  0.645150
# ...              ...       ...       ...       ...        ...       ...
# 2024-01-28  0.023101  0.058594  0.028528  0.043623   0.043623  1.239382
# 2024-02-04  0.015940  0.005960  0.012757  0.014597   0.014597  0.573873
# 2024-02-11  0.008035  0.009122  0.009467  0.008526   0.010101  0.248782
# 2024-02-18  0.010597  0.008758  0.008274  0.011245   0.011245  0.280848
# 2024-02-25       NaN       NaN       NaN       NaN        NaN       NaN
#
# [3243 rows x 6 columns]

# %%
df_pct.resample(rule = 'A').std() # week end frequency by applying std()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 1962-12-31  0.019709  0.015703  0.020017  0.020696   0.020695  1.473296
# 1963-12-31  0.009302  0.008464  0.008882  0.009777   0.009777  0.510236
# 1964-12-31  0.009445  0.008247  0.008889  0.010076   0.010069  0.605220
# 1965-12-31  0.008006  0.007604  0.008152  0.008765   0.008766  1.565291
# 1966-12-31  0.013136  0.012717  0.013523  0.013754   0.013755  0.461536
# ...              ...       ...       ...       ...        ...       ...
# 2020-12-31  0.023051  0.021235  0.022583  0.025746   0.025741  0.670379
# 2021-12-31  0.013272  0.013098  0.013387  0.014605   0.014407  0.567959
# 2022-12-31  0.015251  0.014267  0.015287  0.015267   0.015032  0.429594
# 2023-12-31  0.010347  0.009869  0.009635  0.010161   0.009939  0.514839
# 2024-12-31  0.015215  0.023788  0.015483  0.019940   0.019999  0.555375
#
# [63 rows x 6 columns]

# %%
plt.rcParams['figure.figsize'] = (20.0, 8.0)

df_yearly = df_pct['Close'].resample(rule = 'A').sum() # resampling as A -year end frequency
df_yearly.plot(kind = 'bar')
plt.show()

# %%
# Lead/Lag - shift() for both lead and lag

df.head()
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 1962-01-02  7.374124  7.374124  7.291268  7.291268   1.541711  407940
# 1962-01-03  7.291268  7.355003  7.291268  7.355003   1.555187  305955
# 1962-01-04  7.355003  7.355003  7.278521  7.281708   1.539689  274575
# 1962-01-05  7.272148  7.272148  7.125558  7.138305   1.509367  384405
# 1962-01-08  7.131931  7.131931  6.947100  7.004461   1.481066  572685

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-02-13  184.279999  184.770004  182.360001  183.699997  183.699997
# 2024-02-14  185.000000  185.000000  182.259995  183.570007  183.570007
# 2024-02-15  183.619995  186.979996  183.619995  186.869995  186.869995
# 2024-02-16  186.630005  188.949997  185.949997  187.639999  187.639999
# 2024-02-20  187.639999  188.759995  183.059998  183.440002  183.440002
#
#              Volume
# Date
# 2024-02-13  4290500
# 2024-02-14  3173400
# 2024-02-15  4714300
# 2024-02-16  4841900
# 2024-02-20  4243975

# %%
# lagging data - show yesterday data in today

df.shift(1).head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 1962-01-02       NaN       NaN       NaN       NaN        NaN       NaN
# 1962-01-03  7.374124  7.374124  7.291268  7.291268   1.541711  407940.0
# 1962-01-04  7.291268  7.355003  7.291268  7.355003   1.555187  305955.0
# 1962-01-05  7.355003  7.355003  7.278521  7.281708   1.539689  274575.0
# 1962-01-08  7.272148  7.272148  7.125558  7.138305   1.509367  384405.0

# %%
df.shift(1).tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-02-13  185.899994  186.479996  184.029999  186.160004  186.160004
# 2024-02-14  184.279999  184.770004  182.360001  183.699997  183.699997
# 2024-02-15  185.000000  185.000000  182.259995  183.570007  183.570007
# 2024-02-16  183.619995  186.979996  183.619995  186.869995  186.869995
# 2024-02-20  186.630005  188.949997  185.949997  187.639999  187.639999
#
#                Volume
# Date
# 2024-02-13  4724000.0
# 2024-02-14  4290500.0
# 2024-02-15  3173400.0
# 2024-02-16  4714300.0
# 2024-02-20  4841900.0

# %%
df.shift(5).head(10)
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 1962-01-02       NaN       NaN       NaN       NaN        NaN       NaN
# 1962-01-03       NaN       NaN       NaN       NaN        NaN       NaN
# 1962-01-04       NaN       NaN       NaN       NaN        NaN       NaN
# 1962-01-05       NaN       NaN       NaN       NaN        NaN       NaN
# 1962-01-08       NaN       NaN       NaN       NaN        NaN       NaN
# 1962-01-09  7.374124  7.374124  7.291268  7.291268   1.541711  407940.0
# 1962-01-10  7.291268  7.355003  7.291268  7.355003   1.555187  305955.0
# 1962-01-11  7.355003  7.355003  7.278521  7.281708   1.539689  274575.0
# 1962-01-12  7.272148  7.272148  7.125558  7.138305   1.509367  384405.0
# 1962-01-15  7.131931  7.131931  6.947100  7.004461   1.481066  572685.0

# %%
# Moving Average - use build-in function from Pandas - rolling()

df['Close'].rolling(10) # moving with window = 10 days
# Out:
# Rolling [window=10,center=False,axis=0,method=single]

# %%
df['Close'].rolling(10).std() # moving with window = 10 days of std
# Out:
# Date
# 1962-01-02         NaN
# 1962-01-03         NaN
# 1962-01-04         NaN
# 1962-01-05         NaN
# 1962-01-08         NaN
#                 ...
# 2024-02-13    1.384337
# 2024-02-14    1.392465
# 2024-02-15    1.387315
# 2024-02-16    1.643230
# 2024-02-20    1.641210
# Name: Close, Length: 15640, dtype: float64

# %%
df['sma_fast'] = df['Close'].rolling(10).mean()
df['sma_slow'] = df['Close'].rolling(30).mean()
df.head(40)
# Out:
#                 Open      High       Low     Close  Adj Close  Volume  \
# Date
# 1962-01-02  7.374124  7.374124  7.291268  7.291268   1.541711  407940
# 1962-01-03  7.291268  7.355003  7.291268  7.355003   1.555187  305955
# 1962-01-04  7.355003  7.355003  7.278521  7.281708   1.539689  274575
# 1962-01-05  7.272148  7.272148  7.125558  7.138305   1.509367  384405
# 1962-01-08  7.131931  7.131931  6.947100  7.004461   1.481066  572685
# 1962-01-09  7.036329  7.176546  7.036329  7.087317   1.498586  517770
# 1962-01-10  7.100064  7.131931  7.100064  7.100064   1.501280  313800
# 1962-01-11  7.119184  7.176546  7.119184  7.176546   1.517454  337335
# 1962-01-12  7.189293  7.240280  7.189293  7.189293   1.520149  462855
# 1962-01-15  7.214786  7.237094  7.214786  7.221160   1.526887  266730
# 1962-01-16  7.214786  7.214786  7.144678  7.144678   1.510716  266730
# 1962-01-17  7.112811  7.112811  7.010835  7.029955   1.486458  439320
# ...

# %%
df.loc['2023', ['Close', 'sma_fast', 'sma_slow']].plot()
plt.show()

# %%
# subplot

plt.subplot2grid((4, 4), (0, 0), rowspan = 2, colspan = 4)
plt.subplot2grid((4, 4), (2, 1), rowspan = 2, colspan = 2)
plt.subplot2grid((4, 4), (3, 3))
# Out:
# <AxesSubplot: >

# %%
# add chart to grid

top = plt.subplot2grid((4, 4), (0, 0), rowspan = 2, colspan = 4)
top.plot(df['Close']) # add graph here

# %%
# add chart to grid

top = plt.subplot2grid((4, 4), (0, 0), rowspan = 2, colspan = 4)
top.plot(df['Close']) # add graph here

buttom = plt.subplot2grid((4, 4), (2, 0), rowspan = 1, colspan = 4) # span 1 unit of row and 4 units of columns
buttom.bar(df.index, df['Volume']) # add graph here
# Out:
# <BarContainer object of 15640 artists>

# %%
# add chart to grid

top = plt.subplot2grid((4, 4), (0, 0), rowspan = 2, colspan = 4)
top.plot(df['Close']) # add graph here

buttom = plt.subplot2grid((4, 4), (3, 0), rowspan = 1, colspan = 4) # span 1 unit of row and 4 units of columns
buttom.bar(df.index, df['Volume']) # add graph here
# Out:
# <BarContainer object of 15640 artists>

# %%
# MPL Finance

import mplfinance as mpf

# %%
# pip install --upgrade mplfinance

# %%
df.loc['2023-12']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-12-01  158.410004  160.589996  158.000000  160.550003  159.099518
# 2023-12-04  160.289993  162.789993  160.289993  161.100006  159.644547
# 2023-12-05  160.759995  162.470001  160.720001  161.389999  159.931915
# 2023-12-06  161.589996  162.350006  160.009995  160.279999  158.831940
# 2023-12-07  161.000000  161.470001  159.970001  160.220001  158.772491
# 2023-12-08  160.000000  162.039993  160.000000  161.960007  160.496780
# 2023-12-11  162.679993  163.649994  161.949997  163.509995  162.032761
# 2023-12-12  163.270004  166.339996  162.919998  164.710007  163.221939
# 2023-12-13  164.369995  164.970001  162.740005  163.619995  162.141769
# 2023-12-14  162.929993  163.500000  160.149994  162.910004  161.438187
# 2023-12-15  162.300003  164.089996  162.039993  162.229996  160.764328
# 2023-12-18  162.229996  163.330002  161.580002  162.740005  161.269730
# ...

# %%
mpf.plot(df) # plot all time
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/conda_env/lib/python3.9/site-packages/mplfinance/_arg_validators.py:84: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+

# %%
mpf.plot(df.loc['2023-12'])

# %%
mpf.plot(df.loc['2023-12'], type = 'candle')

# %%
mpf.plot(df.loc['2023-12'], type = 'candle', volume = True)

# %%
# check styles

mpf.available_styles()
# Out:
# ['binance',
#  'binancedark',
#  'blueskies',
#  'brasil',
#  'charles',
#  'checkers',
#  'classic',
#  'default',
#  'ibd',
#  'kenan',
#  'mike',
#  'nightclouds',
#  'sas',
#  'starsandstripes',
#  'tradingview',
#  'yahoo']

# %%
mpf.plot(df.loc['2023-12'], type = 'candle', volume = True, mav = (20, 5), style = 'binance')

# %%
mpf.plot(df.loc['2023-12'], type = 'candle', volume = True, mav = (20, 5), style = 'tradingview')

# %%
mpf.plot(df.loc['2023-12'], type = 'candle', volume = True, mav = (20, 5), style = 'yahoo', hlines = [157, 167])
