# %%
import simfin
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import simfin
#
# ModuleNotFoundError: No module named 'simfin'

# %%
pip install simfin
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 820.7 kB/s eta 0:00:000:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ![Screenshot 2567-04-08 at 07.19.16.png](<attachment:Screenshot 2567-04-08 at 07.19.16.png>)

# %%
import simfin as sf
