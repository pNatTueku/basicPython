# %% [markdown]
# ### Basic plot using matplotlib
#
# - Learn from Aj. Prasert CBS

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 3, 7, 2]) # pass list or tuple to plot - y values
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 3, 7, 2]) # pass list or tuple to plot - both x and y value
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 3, 7, 2], "o") # pass list or tuple to plot - both x and y value
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 3, 7, 2], "ro") # pass list or tuple to plot - both x and y value
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 3, 7, 2], 'ro-') # pass list or tuple to plot - both x and y value
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 3, 7, 2], 'ro-') # pass list or tuple to plot - both x and y value
plt.plot([1, 2, 3, 4], [1, 5, 3, 4], 'go-')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 3, 7, 2], 'ro-') # pass list or tuple to plot - both x and y value
plt.plot([1, 2, 3, 4], [1, 5, 3, 4], 'go-')
plt.plot([1, 2, 3, 4], [1, 3, 5, 7], 'ko-')
plt.show()

# %%
def demo_plot():
    plt.plot([1, 3, 7, 2]) # no define x, so python will start the x with 0
    plt.show()

if __name__ == '__main__':
    demo_plot()

# %%
def demo_plot():
    plt.plot([1, 3, 7, 2]) # no define x, so python will start the x with 0
    plt.plot([1, 5, 3, 4])
    plt.show()

if __name__ == '__main__':
    demo_plot()

# %%
def demo_plot():
    plt.plot([1, 3, 7, 2], color = 'green') # no define x, so python will start the x with 0
    plt.plot([1, 5, 3, 4], color = 'blue')
    plt.show()

if __name__ == '__main__':
    demo_plot()

# %%
def demo_plot():
    plt.plot([1, 3, 7, 2], color = 'green', marker = 'o') # no define x, so python will start the x with 0
    plt.plot([1, 5, 3, 4], color = 'blue', linestyle = "--")
    plt.show()

if __name__ == '__main__':
    demo_plot()

# %%
def demo_plot():
    plt.plot([1, 3, 7, 2], color = 'green', marker = 'o') # no define x, so python will start the x with 0
    plt.plot([1, 5, 3, 4], color = 'blue', linestyle = "--")
    plt.show()

def demo_plot2():
    plt.plot([2014, 2015, 2016, 2017], [1, 3, 7, 2], color = 'green', marker = 'o') # no define x, so python will start the x with 0
    plt.plot(range(2014, 2018), [1, 5, 3, 4], color = 'blue', linestyle = "--")
    plt.show()

if __name__ == '__main__':
    demo_plot()
    demo_plot2()

# %%
def demo_plot():
    plt.plot([1, 3, 7, 2], color = 'green', marker = 'o') # no define x, so python will start the x with 0
    plt.plot([1, 5, 3, 4], color = 'blue', linestyle = "--")
    plt.show()

def demo_plot2():
    plt.plot([2014, 2015, 2016, 2017], [1, 3, 7, 2], color = 'green', marker = 'o') # no define x, so python will start the x with 0
    plt.plot(range(2014, 2018), [1, 5, 3, 4], color = 'blue', linestyle = "--")
    plt.show()

def demo_plot3():
    x = range(2017, 2024)
    y = [10, 25, 15, 20, 22, 18, 7]
    plt.plot(x, y)
    plt.show()

if __name__ == '__main__':
    # demo_plot()
    # demo_plot2()
    demo_plot3()

# %%
def demo_plot():
    plt.plot([1, 3, 7, 2], color = 'green', marker = 'o') # no define x, so python will start the x with 0
    plt.plot([1, 5, 3, 4], color = 'blue', linestyle = "--")
    plt.show()

def demo_plot2():
    plt.plot([2014, 2015, 2016, 2017], [1, 3, 7, 2], color = 'green', marker = 'o') # no define x, so python will start the x with 0
    plt.plot(range(2014, 2018), [1, 5, 3, 4], color = 'blue', linestyle = "--")
    plt.show()

def demo_plot3():
    x = range(2017, 2024)
    y = [10, 25, 15, 20, 22, 18, 7]
    plt.plot(x, y)
    plt.show()

def demo_plot4():
    x = range(2017, 2024)
    y = [10, 25, 15, 20, 22, 18, 7]
    plt.plot(x[:4], y[:4]) # slice to plot
    plt.show()

if __name__ == '__main__':
    # demo_plot()
    # demo_plot2()
    # demo_plot3()
    demo_plot4()

# %%
def demo_plot():
    plt.plot([1, 3, 7, 2], color = 'green', marker = 'o') # no define x, so python will start the x with 0
    plt.plot([1, 5, 3, 4], color = 'blue', linestyle = "--")
    plt.show()

def demo_plot2():
    plt.plot([2014, 2015, 2016, 2017], [1, 3, 7, 2], color = 'green', marker = 'o') # no define x, so python will start the x with 0
    plt.plot(range(2014, 2018), [1, 5, 3, 4], color = 'blue', linestyle = "--")
    plt.show()

def demo_plot3():
    x = range(2017, 2024)
    y = [10, 25, 15, 20, 22, 18, 7]
    plt.plot(x, y)
    plt.show()

def demo_plot4():
    x = range(2017, 2024)
    y = [10, 25, 15, 20, 22, 18, 7]
    plt.plot(x[:4], y[:4]) # slice to plot
    plt.plot(x[3:], y[3:]) # slice to plot as the forecast values
    plt.show()

if __name__ == '__main__':
    # demo_plot()
    # demo_plot2()
    # demo_plot3()
    demo_plot4()

# %%
def demo_plot():
    plt.plot([1, 3, 7, 2], color = 'green', marker = 'o') # no define x, so python will start the x with 0
    plt.plot([1, 5, 3, 4], color = 'blue', linestyle = "--")
    plt.show()

def demo_plot2():
    plt.plot([2014, 2015, 2016, 2017], [1, 3, 7, 2], color = 'green', marker = 'o') # no define x, so python will start the x with 0
    plt.plot(range(2014, 2018), [1, 5, 3, 4], color = 'blue', linestyle = "--")
    plt.show()

def demo_plot3():
    x = range(2017, 2024)
    y = [10, 25, 15, 20, 22, 18, 7]
    plt.plot(x, y)
    plt.show()

def demo_plot4():
    x = range(2017, 2024)
    y = [10, 25, 15, 20, 22, 18, 7]
    plt.plot(x[:4], y[:4], color = 'deepskyblue') # slice to plot
    plt.plot(x[3:], y[3:], color = "deepskyblue", linestyle = "--") # slice to plot as the forecast values
    plt.show()

if __name__ == '__main__':
    # demo_plot()
    # demo_plot2()
    # demo_plot3()
    demo_plot4()

# %%
def demo_plot():
    plt.plot([1, 3, 7, 2], color = 'green', marker = 'o') # no define x, so python will start the x with 0
    plt.plot([1, 5, 3, 4], color = 'blue', linestyle = "--")
    plt.show()

def demo_plot2():
    plt.plot([2014, 2015, 2016, 2017], [1, 3, 7, 2], color = 'green', marker = 'o') # no define x, so python will start the x with 0
    plt.plot(range(2014, 2018), [1, 5, 3, 4], color = 'blue', linestyle = "--")
    plt.show()

def demo_plot3():
    x = range(2017, 2024)
    y = [10, 25, 15, 20, 22, 18, 7]
    plt.plot(x, y)
    plt.show()

def demo_plot4():
    x = range(2017, 2024)
    y = [10, 25, 15, 20, 22, 18, 7]
    plt.plot(x[:4], y[:4], color = 'deepskyblue') # slice to plot
    plt.plot(x[3:], y[3:], color = "deepskyblue", linestyle = "--") # slice to plot as the forecast values
    plt.title('Sales Forecast')
    plt.ylabel("Sales ('000)")
    plt.xlabel("Year")
    plt.show()

if __name__ == '__main__':
    # demo_plot()
    # demo_plot2()
    # demo_plot3()
    demo_plot4()

# %%
def demo_plot():
    plt.plot([1, 3, 7, 2], color = 'green', marker = 'o') # no define x, so python will start the x with 0
    plt.plot([1, 5, 3, 4], color = 'blue', linestyle = "--")
    plt.show()

def demo_plot2():
    plt.plot([2014, 2015, 2016, 2017], [1, 3, 7, 2], color = 'green', marker = 'o') # no define x, so python will start the x with 0
    plt.plot(range(2014, 2018), [1, 5, 3, 4], color = 'blue', linestyle = "--")
    plt.show()

def demo_plot3():
    x = range(2017, 2024)
    y = [10, 25, 15, 20, 22, 18, 7]
    plt.plot(x, y)
    plt.show()

def demo_plot4():
    x = range(2017, 2024)
    y = [10, 25, 15, 20, 22, 18, 7]
    plt.plot(x[:4], y[:4], color = 'deepskyblue', label = 'Actual') # slice to plot
    plt.plot(x[3:], y[3:], color = "deepskyblue", linestyle = "--", label = 'Forecast') # slice to plot as the forecast values
    plt.title('Sales Forecast')
    plt.ylabel("Sales ('000)")
    plt.xlabel("Year")
    plt.legend()
    plt.show()

if __name__ == '__main__':
    # demo_plot()
    # demo_plot2()
    # demo_plot3()
    demo_plot4()

# %%
# style

x = range(2017, 2024)
y = [10, 25, 15, 20, 22, 18, 7]

plt.style.use('classic')
plt.plot(x[:4], y[:4], color = 'deepskyblue', label = 'Actual') # slice to plot
plt.plot(x[3:], y[3:], color = "deepskyblue", linestyle = "--", label = 'Forecast') # slice to plot as the forecast values
plt.title('Sales Forecast')
plt.ylabel("Sales ('000)")
plt.xlabel("Year")
plt.legend()
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# style

x = range(2017, 2024)
y = [10, 25, 15, 20, 22, 18, 7]

plt.style.use('ggplot')
plt.plot(x[:4], y[:4], color = 'deepskyblue', label = 'Actual') # slice to plot
plt.plot(x[3:], y[3:], color = "deepskyblue", linestyle = "--", label = 'Forecast') # slice to plot as the forecast values
plt.title('Sales Forecast')
plt.ylabel("Sales ('000)")
plt.xlabel("Year")
plt.legend()
plt.show()

# %%
# style

x = range(2017, 2024)
y = [10, 25, 15, 20, 22, 18, 7]

plt.style.use('dark_background')
plt.plot(x[:4], y[:4], color = 'deepskyblue', label = 'Actual') # slice to plot
plt.plot(x[3:], y[3:], color = "deepskyblue", linestyle = "--", label = 'Forecast') # slice to plot as the forecast values
plt.title('Sales Forecast')
plt.ylabel("Sales ('000)")
plt.xlabel("Year")
plt.legend()
plt.show()

# %%
# style

x = range(2017, 2024)
y = [10, 25, 15, 20, 22, 18, 7]

plt.style.use('dark_background')
plt.plot(x[:4], y[:4], color = 'deepskyblue', label = 'Actual') # slice to plot
plt.plot(x[3:], y[3:], color = "deepskyblue", linestyle = "--", label = 'Forecast') # slice to plot as the forecast values
plt.title('Sales Forecast')
plt.ylabel("Sales ('000)")
plt.xlabel("Year")
plt.legend()
plt.show()

# %%
# style

x = range(2017, 2024)
y = [10, 25, 15, 20, 22, 18, 7]

plt.style.use('fivethirtyeight')
plt.plot(x[:4], y[:4], color = 'deepskyblue', label = 'Actual') # slice to plot
plt.plot(x[3:], y[3:], color = "deepskyblue", linestyle = "--", label = 'Forecast') # slice to plot as the forecast values
plt.title('Sales Forecast')
plt.ylabel("Sales ('000)")
plt.xlabel("Year")
plt.legend()
plt.show()

# %%
# informal style

# style

x = range(2017, 2024)
y = [10, 25, 15, 20, 22, 18, 7]

with plt.xkcd():
    plt.plot(x[:4], y[:4], color = 'deepskyblue', label = 'Actual') # slice to plot
    plt.plot(x[3:], y[3:], color = "deepskyblue", linestyle = "--", label = 'Forecast') # slice to plot as the forecast values
    plt.title('Sales Forecast')
    plt.ylabel("Sales ('000)")
    plt.xlabel("Year")
    plt.legend()
    plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
# style

x = range(2017, 2024)
y = [10, 25, 15, 20, 22, 18, 7]

plt.style.use('seaborn-v0_8')
plt.plot(x[:4], y[:4], color = 'deepskyblue', label = 'Actual') # slice to plot
plt.plot(x[3:], y[3:], color = "deepskyblue", linestyle = "--", label = 'Forecast') # slice to plot as the forecast values
plt.title('Sales Forecast')
plt.ylabel("Sales ('000)")
plt.xlabel("Year")
plt.legend()
plt.show()

# %%
# style

x = range(2017, 2024)
y = [10, 25, 15, 20, 22, 18, 7]

plt.xkcd()
plt.plot(x[:4], y[:4], color = 'deepskyblue', label = 'Actual') # slice to plot
plt.plot(x[3:], y[3:], color = "deepskyblue", linestyle = "--", label = 'Forecast') # slice to plot as the forecast values
plt.title('Sales Forecast')
plt.ylabel("Sales ('000)")
plt.xlabel("Year")
plt.legend()
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...
