# %% [markdown]
# How to process: `Create a for loop and perform these processes`
# - Read in the file by excluding some rows
# - Create a new column and assign the file name
# - create a date column based on the filename
# - append the files to dataframe

# %%
import pandas as pd
import os

# %%
pd.options.display.max_colwidth
# Out:
# 50

# %%
# files paths

path = r'multiple_csv/'
files = os.listdir(path)
files
# Out:
# ['AB012401_20230601_182004_PRO01_AB123460_none_AB123461_414X11.csv',
#  'AB012002_20230601_180308_PRO01_AB123458_none_AB123459_414X10.csv',
#  'AB013005_20230601_182410_PRO01_AB123463_none_AB123464_414X12.csv']

# %%
combined_df = pd.DataFrame()
combined_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
type(combined_df)
# Out:
# pandas.core.frame.DataFrame

# %%
len(combined_df)
# Out:
# 0

# %%
for file in files:

    temp_df = pd.read_csv(path + file, skiprows = [5], skip_blank_lines = True)
    temp_df['filename'] = file
    temp_df['date'] = file.split('_')[1]
    combined_df = combined_df.append(temp_df)

combined_df
# Out:
# /var/folders/0z/2gy2pkss67v3rwygb64_tfvm0000gn/T/ipykernel_70367/1141977305.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df = combined_df.append(temp_df)
# /var/folders/0z/2gy2pkss67v3rwygb64_tfvm0000gn/T/ipykernel_70367/1141977305.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df = combined_df.append(temp_df)
# /var/folders/0z/2gy2pkss67v3rwygb64_tfvm0000gn/T/ipykernel_70367/1141977305.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df = combined_df.append(temp_df)
#    YYYY  MM  DD  hh  mm  ss  AmpsCells CCCType  \
# 0  2023   6   1  21  29  19      0.865   ABC01
# 1  2023   6   1  21  31  21      0.842   ABC01
# 2  2023   6   1  21  32  33      0.840   ABC01
# ...

# %%
all_df = pd.DataFrame()
all_df.shape
# Out:
# (0, 0)

# %%
for file in files:

    temp_df = pd.read_csv(path + file, skiprows = [5], skip_blank_lines = True)
    temp_df['filename'] = file
    temp_df['date'] = file.split('_')[1]
    temp_df['ccc_sn'] = file.split('_')[-1][:-4]
    all_df = all_df.append(temp_df)

all_df
# Out:
# /var/folders/0z/2gy2pkss67v3rwygb64_tfvm0000gn/T/ipykernel_70367/2462601936.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_df = all_df.append(temp_df)
# /var/folders/0z/2gy2pkss67v3rwygb64_tfvm0000gn/T/ipykernel_70367/2462601936.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_df = all_df.append(temp_df)
# /var/folders/0z/2gy2pkss67v3rwygb64_tfvm0000gn/T/ipykernel_70367/2462601936.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_df = all_df.append(temp_df)
#    YYYY  MM  DD  hh  mm  ss  AmpsCells CCCType  \
# 0  2023   6   1  21  29  19      0.865   ABC01
# 1  2023   6   1  21  31  21      0.842   ABC01
# 2  2023   6   1  21  32  33      0.840   ABC01
# ...

# %%
all_df['AmpsCells'].describe()
# Out:
# count    12.000000
# mean      0.845167
# std       0.013217
# min       0.814000
# 25%       0.841500
# 50%       0.843000
# 75%       0.850250
# max       0.865000
# Name: AmpsCells, dtype: float64

# %%
all_df.describe()
# Out:
#          YYYY    MM    DD         hh         mm         ss  AmpsCells
# count    12.0  12.0  12.0  12.000000  12.000000  12.000000  12.000000
# mean   2023.0   6.0   1.0  21.666667  34.750000  26.416667   0.845167
# std       0.0   0.0   0.0   1.775251  13.239919  12.383701   0.013217
# min    2023.0   6.0   1.0  20.000000  19.000000  11.000000   0.814000
# 25%    2023.0   6.0   1.0  20.000000  22.750000  16.000000   0.841500
# 50%    2023.0   6.0   1.0  21.000000  31.500000  23.500000   0.843000
# 75%    2023.0   6.0   1.0  24.000000  49.500000  39.000000   0.850250
# max    2023.0   6.0   1.0  24.000000  54.000000  43.000000   0.865000

# %%
all_df['AmpsCells'].plot()
# Out:
# <AxesSubplot: >

# %%
all_df
# Out:
#    YYYY  MM  DD  hh  mm  ss  AmpsCells CCCType  \
# 0  2023   6   1  21  29  19      0.865   ABC01
# 1  2023   6   1  21  31  21      0.842   ABC01
# 2  2023   6   1  21  32  33      0.840   ABC01
# 3  2023   6   1  21  34  26      0.814   ABC01
# 0  2023   6   1  20  49  39      0.861   ABC01
# 1  2023   6   1  20  51  11      0.843   ABC01
# 2  2023   6   1  20  52  43      0.842   ABC01
# 3  2023   6   1  20  54  16      0.840   ABC01
# 0  2023   6   1  24  19  39      0.860   ABC01
# 1  2023   6   1  24  21  11      0.845   ABC01
# 2  2023   6   1  24  22  43      0.843   ABC01
# 3  2023   6   1  24  23  16      0.847   ABC01
#
#                                             filename      date  ccc_sn
# 0  AB012401_20230601_182004_PRO01_AB123460_none_A...  20230601  414X11
# 1  AB012401_20230601_182004_PRO01_AB123460_none_A...  20230601  414X11
# 2  AB012401_20230601_182004_PRO01_AB123460_none_A...  20230601  414X11
# ...
