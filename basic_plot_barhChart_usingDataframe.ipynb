# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# create a dataframe

replaced_part_dict = {
    "Replace screw": 77,
    "Replace shockmount": 49,
    "Replace fan": 22,
    "Replace retainer": 9,
    "Replace gear": 5,
    "Replace LED": 5,
    "Replace nut": 4,
    "Replace gasket": 1
}

replaced_part_df = pd.DataFrame(replaced_part_dict.items(), columns = ['repair_action', 'count'])
replaced_part_df
# Out:
#         repair_action  count
# 0       Replace screw     77
# 1  Replace shockmount     49
# 2         Replace fan     22
# 3    Replace retainer      9
# 4        Replace gear      5
# 5         Replace LED      5
# 6         Replace nut      4
# 7      Replace gasket      1

# %%
replaced_part_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   repair_action  8 non-null      object
#  1   count          8 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 256.0+ bytes

# %%
replaced_part_df.describe()
# Out:
#            count
# count   8.000000
# mean   21.500000
# std    27.422618
# min     1.000000
# 25%     4.750000
# 50%     7.000000
# 75%    28.750000
# max    77.000000

# %%
# visualize repair action count and percentage

plt.rcParams['figure.figsize'] = [10, 5]
plt.rcParams['figure.autolayout'] = True

ax = replaced_part_df.plot.barh(x = 'repair_action', y = 'count')

# %%
# visualize repair action count and percentage

plt.rcParams['figure.figsize'] = [10, 5]
plt.rcParams['figure.autolayout'] = True

ax = replaced_part_df.plot.barh(x = 'repair_action', y = 'count')
ax.invert_yaxis()

# %%
# visualize repair action count and percentage

plt.rcParams['figure.figsize'] = [10, 5]
plt.rcParams['figure.autolayout'] = True

ax = replaced_part_df.plot.barh(x = 'repair_action', y = 'count')
ax.invert_yaxis()
ax.set(title = 'Repair Action') # add title
sns.despine(bottom = False) # remove right and top axis

# %%
# visualize repair action count and percentage

plt.rcParams['figure.figsize'] = [10, 5]
plt.rcParams['figure.autolayout'] = True

ax = replaced_part_df.plot.barh(x = 'repair_action', y = 'count')
ax.invert_yaxis()
ax.set(title = 'Repair Action') # add title
sns.despine(bottom = False) # remove right and top axis

total = sum(replaced_part_df['count']) # sum total

for p in ax.patches:

    count_repair_action = '{:.0f}'.format(p.get_width())
    percent_repair_action = '{:.2f}%'.format(100*p.get_width()/total)

    x = p.get_x() + p.get_width() + 0.02
    y = p.get_y() + p.get_height() / 2

plt.show()

# %%
# visualize repair action count and percentage

plt.rcParams['figure.figsize'] = [10, 5]
plt.rcParams['figure.autolayout'] = True

ax = replaced_part_df.plot.barh(x = 'repair_action', y = 'count')
ax.invert_yaxis()
ax.set(title = 'Repair Action') # add title
sns.despine(bottom = False) # remove right and top axis

total = sum(replaced_part_df['count']) # sum total

for p in ax.patches:

    count_repair_action = '{:.0f}'.format(p.get_width())
    percent_repair_action = '{:.2f}%'.format(100*p.get_width()/total)

    x = p.get_x() + p.get_width() + 0.02
    y = p.get_y() + p.get_height() / 2

    ax.annotate(str(count_repair_action) + ', ' + str(percent_repair_action), (x, y))

plt.show()
