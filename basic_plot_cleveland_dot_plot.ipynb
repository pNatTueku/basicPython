# %% [markdown]
# ### Basic Plot - Cleveland Dot Plot
#
# - Learn from Aj. Prasert CBS
# - YouTube: https://www.youtube.com/prasertcbs
# - Datasource: export mtcars data to a csv from R Studio

# %%
# import libraries

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# create a function and test 

def demo():

    df = pd.read_csv("mtcars.csv")
    df.columns = df.columns.str.replace('Unnamed: 0', 'model')
    df.sort_values("mpg", inplace = True)
    print(df.head())

if __name__ == '__main__':
    demo()
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
#
#     gear  carb
# 15     3     4
# 14     3     4
# 23     3     4
# 6      3     4
# 16     3     4

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


def demo():
    df = pd.read_csv("mtcars.csv")
    df.columns = df.columns.str.replace('Unnamed: 0', 'model')
    df.sort_values("mpg", inplace = True)
    # print(df.head())

    x = np.arange(df.model.size)
    y = df.mpg * 0.425144 # convert miles/gallon to kilos/litre

    fig, ax = plt.subplots()
    plt.barh(x, y) # horozontal plot
    plt.show()


if __name__ == '__main__':
    demo()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


def demo():
    df = pd.read_csv("mtcars.csv")
    df.columns = df.columns.str.replace('Unnamed: 0', 'model')
    df.sort_values("mpg", inplace = True)
    # print(df.head())

    x = np.arange(df.model.size)
    y = df.mpg * 0.425144 # convert miles/gallon to kilos/litre

    fig, ax = plt.subplots()
    plt.barh(x, y) # horozontal plot
    plt.yticks(x, df.model)
    plt.show()


if __name__ == '__main__':
    demo()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


def demo():
    df = pd.read_csv("mtcars.csv")
    df.columns = df.columns.str.replace('Unnamed: 0', 'model')
    df.sort_values("mpg", inplace = True)
    # print(df.head())

    x = np.arange(df.model.size)
    y = df.mpg * 0.425144 # convert miles/gallon to kilos/litre

    fig, ax = plt.subplots()
    plt.barh(x, y, height = .1, color = ".9") # horozontal plot, grey line
    plt.yticks(x, df.model)
    plt.show()


if __name__ == '__main__':
    demo()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


def demo():
    df = pd.read_csv("mtcars.csv")
    df.columns = df.columns.str.replace('Unnamed: 0', 'model')
    df.sort_values("mpg", inplace = True)
    # print(df.head())

    x = np.arange(df.model.size)
    y = df.mpg * 0.425144 # convert miles/gallon to kilos/litre

    fig, ax = plt.subplots()
    plt.barh(x, y, height = .1, color = ".9") # horozontal plot, grey line
    plt.yticks(x, df.model)
    plt.scatter(y, x) # add point by using scatter for all point to the line
    plt.show()


if __name__ == '__main__':
    demo()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


def demo():
    df = pd.read_csv("mtcars.csv")
    df.columns = df.columns.str.replace('Unnamed: 0', 'model')
    df.sort_values("mpg", inplace = True)
    # print(df.head())

    x = np.arange(df.model.size)
    y = df.mpg * 0.425144 # convert miles/gallon to kilos/litre

    fig, ax = plt.subplots()
    plt.barh(x, y, height = .1, color = ".9", zorder = -1)
    plt.yticks(x, df.model, fontsize = 6)
    plt.scatter(y, x, color = "yellow") # add point by using scatter for all point to the line - horizontal bar to swap x and y
    plt.scatter(y[y >= 12], x[y >= 12], color = "green") #cassign color to some points
    plt.scatter(y[y < 8], x[y < 8], color = "red")

    plt.axvline(x = 12, color = "green", alpha = .5, linestyle = "--")
    plt.axvline(x = 8, color = "red", alpha = .5, linestyle = "--")
    
    plt.xlabel("kilometre per litre")
    plt.title("Fuel efficiency")
    fig.tight_layout()
    plt.show()

if __name__ == '__main__':
    demo()
