# %% [markdown]
# ### install Yahoo finance libraries
#
# #### pip install yfinance

# %%
# import libraries

import pandas as pd 
import yfinance as yf 

import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
# get data from Yahoo finance

data = yf.Ticker('PTT.BK')
data
# Out:
# yfinance.Ticker object <PTT.BK>

# %%
data.info
# Out:
# {'address1': '555 Vibhavadi-Rangsit Road',
#  'address2': 'Chatuchak',
#  'city': 'Bangkok',
#  'zip': '10900',
#  'country': 'Thailand',
#  'phone': '66 2 537 2000',
#  'fax': '66 2 537 3498',
#  'website': 'https://www.pttplc.com',
#  'industry': 'Oil & Gas Integrated',
#  'industryKey': 'oil-gas-integrated',
#  'industryDisp': 'Oil & Gas Integrated',
#  'sector': 'Energy',
#  'sectorKey': 'energy',
#  'sectorDisp': 'Energy',
# ...

# %%
type(data)
# Out:
# yfinance.ticker.Ticker

# %%
# get data to Pandas series

pd.Series(data.info)
# Out:
# address1             555 Vibhavadi-Rangsit Road
# address2                              Chatuchak
# city                                    Bangkok
# zip                                       10900
# country                                Thailand
#                                 ...
# grossMargins                            0.11495
# ebitdaMargins                           0.13544
# operatingMargins                        0.04673
# financialCurrency                           THB
# trailingPegRatio                           None
# Length: 118, dtype: object

# %%
pd.Series(data.info).head(20)
# Out:
# address1                                            555 Vibhavadi-Rangsit Road
# address2                                                             Chatuchak
# city                                                                   Bangkok
# zip                                                                      10900
# country                                                               Thailand
# phone                                                            66 2 537 2000
# fax                                                              66 2 537 3498
# website                                                 https://www.pttplc.com
# industry                                                  Oil & Gas Integrated
# industryKey                                                 oil-gas-integrated
# industryDisp                                              Oil & Gas Integrated
# sector                                                                  Energy
# ...

# %%
data.history()
# Out:
#                             Open   High    Low  Close    Volume  Dividends  \
# Date
# 2024-01-19 00:00:00+07:00  34.00  34.50  34.00  34.25  55437000        0.0
# 2024-01-22 00:00:00+07:00  34.25  34.25  33.75  34.00  20909000        0.0
# 2024-01-23 00:00:00+07:00  34.25  34.25  33.50  34.00  38875800        0.0
# 2024-01-24 00:00:00+07:00  34.00  34.25  33.75  34.25  28836900        0.0
# 2024-01-25 00:00:00+07:00  34.25  34.50  34.00  34.25  21760400        0.0
# 2024-01-26 00:00:00+07:00  34.25  34.50  34.00  34.00  16987200        0.0
# 2024-01-29 00:00:00+07:00  34.50  34.50  34.00  34.50  28776500        0.0
# 2024-01-30 00:00:00+07:00  34.25  34.25  34.00  34.00  35241900        0.0
# 2024-01-31 00:00:00+07:00  34.00  34.25  33.75  33.75  47266600        0.0
# 2024-02-01 00:00:00+07:00  34.00  34.25  33.75  34.25  36959700        0.0
# 2024-02-02 00:00:00+07:00  34.25  34.25  34.00  34.00  19403200        0.0
# ...

# %%
data.history(period = '3mo')
# Out:
#                             Open   High    Low  Close    Volume  Dividends  \
# Date
# 